# %% [markdown]
# # Zomato Recommendation Engine
#
# Make a restaurant recommendation engine for Zomato using user review data.
#
# ![alt text](zomato-banner.png)
#
# ## Prologue
#
# You have been lucky and after graduation got employed as a Data Engineer at Zomato. You have been living in Mumbai, spending your big fat check, but due to the recent emergence of Swiggy, Zomato is now facing a major competitor in the market. Your boss Dr Mukherjee, given the situation, has assigned you to improve the recommendation engine employed at Zomato. It is now upon you to keep your stocks floating and grab that year-end bonus.
#
# It has been two days since you were assigned the project, you researched about recommender systems, for which you found [this blog](https://towardsdatascience.com/brief-on-recommender-systems-b86a1068a4dd) extremely helpful. After reading the blog, you decided to make a **collaborative filtering based recommendation system using autoencoders**, since Zomato was already using content-based filtering which wasn't giving promising results. You decided to use user review data on restaurants situated in Mumbai since it has a high user engagement. Following are the notes, you made while researching:
#
# <!-- In this assignment, we will be working on implementing a recommendation system on Zomato's user reviews data for different restaurants. We will be using a technique called Collaborative Filtering which is one of the most popular ways of implementing a recommendation system and we will be training an autoencoder. Don't be afraid if you have never heard these terms before we will be explaining them in detail. -->
#
# ## Collaborative Filtering
#
# Let's say we have ratings of 5 users on 4 different restaurants and a user might not have rated a particular restaurant. We can create arrange the ratings in a user-restaurant matrix from the data, that looks like this:
#
# ![alt text](data.png)
#
# As you can see the users have not rated all the restaurants. In collaborative filtering we try to find these missing values and based on these values we make a recommendation to them. In this figure, for example, Kabir has rated ANC and Looters but not Food King, however Suvigya has rated all three of these restaurants. We can observe that the ratings of Suvigya on ANC and Looters match a lot with Kabir and we can to some extent say that Kabir's rating for Food King will be close to 2.
#
# ## Autoencoders
#
# **Youtube Video:** https://www.youtube.com/watch?v=9zKuYvjFFS8 (till 5:36)
#
# An autoencoder is a neural network which learns to copy its input to its output. The network can be viewed as consisting 2 parts, an encoder which downsamples the input to a compact representation and a decoder which produces a reconstruction of the input. Autoencoders falls under the area of unsupervised learning algorithms, since for training an autoencoder we only need raw data without any label. An autoencoder with one hidden layer is shown below:
#
#
# ![alt text](autoencoder.png)
#
# Please note that we can have as many layers as we want in our autoencoder. The only thing to keep in mind is to reduce the dimensionality of the input in the encoder part of the network and increase the dimensionality of the hidden representation to the size of actual input in decoder network.
#
# Once we have defined the architecture of our autoencoder, we can train it using the following steps:
#
# 1.   Feed the batch of inputs *x* to the network and obtain the predictions *p*
# 2.   Compute the loss between the reconstructed inputs *p* and the actual inputs *x* i.e. *L(p,x)*
# 3. Compute the gradients of this loss with respect to the parameters of the model using backprop.
# 4. Use these gradients to take optimization step, for e.g. Stochastic Gradient Descent.
# 5. Repeat steps 1-4 till convergence.
#
# ## Collaborative Filtering using Autoencoders
#
# We will now see how to use autoencoders for collaborative filtering. Lets first see the steps involved in training an autoencoder for this problem and then we will develope an intuition on why it works.
#
# ![alt text](autoencoder2.png)
#
# In the figure we are feeding Kabir's ratings to the autoencoder. Note that the ratings corresponding to the missing values are kept zero. After computing the predictions of autoencoder we compute mean squared error between the input ratings and the ratings predicting by the network. One important thing to note here is that while computing the loss we do not consider the predictions corresponding to 0 ratings i.e. the missing values and only compute the error for the ratings that we are given. This is because we do not want our network to learn that the output corresponding to the missing values is zero but instead learn a reasonable value. We repeat the same thing for other users and then backprogate the gradients and take optimization steps.
#
# During test time we will feed the input with the missing ratings to the network and use the output of the network to determine the ratings of the missing values. Once we have the ratings for those missing values we can make a recommendation accordingly.
#
# ![alt text](autoencoder3.png)

# %% [markdown]
# After reading your notes, you decided to proceed with building the recommendation engine.
#
# Fortunately, you don't have to worry about the data collection as your team member Suvigya has already collected the data from Zomato's website in the required format using the code [here](https://github.com/suvigyavijay/zomato-scraper).
#
# ![alt text](restaurants_data.png)
#
# ![alt text](review_data.png)

# %% [markdown]
# After the data collection, another team member, Kabir helped out and extracted the ratings and preprocessed it. Finally, he provided you with the train-test split, in order to ensure that you spent more time on designing the algorithm instead of engineering the data.

# %%
#Loading necessary packages and defining global variables
import numpy as np
import torch.nn as nn
import torch
import torch.optim as optim
from collections import defaultdict
import os
from torch.utils import data
import matplotlib.pyplot as plt
import pandas as pd
from sys import platform

torch.manual_seed(0)
np.random.seed(0)
device = torch.device("cpu")
OUTPUT_DIR_TRAIN='data/train.dat'
OUTPUT_DIR_TEST='data/test1.dat'

NUM_RESTS = 5138
NUM_USERS = 3579

# %% [markdown]
# ## Restaurant reviews data
#
# We have reviews of 5138 restaurants from 3579 different users. Each user is given an ID from 0 to 3578 and similarly, each restaurant is given an ID from 0 to 5137. We have provided you 3 files `train.dat` and `test1.dat` and `test_hidden.dat` containing training data, testing data and hidden test data respectively. For now, do not worry about `train_hidden.dat`. The format of data in the other 2 files is:
#
#                         userID, restaurantID, rating
#
# This means each row contains a rating given to a particular restaurant by a given user. Please have a look at the files and ensure what we said makes sense. The figure below shows how the split has been made from the original data to training and test set.
#
# ![alt text](datasplit.png)
#
# We have removed some ratings from each user at random from train set and added them to test set. This way we can compare the final predictions on the train set and compare with ratings present in the test set, to find out how the network is actually performing.
#
# During training, we use the rating data from the `train.dat` file to train our autoencoder. During testing though we feed the data from `train.dat` to the autoencoder and compare the predictions with the values given in `test.dat`. The figure given below demonstrates the testing process.
#
# ![alt text](testing.png)
#
# `test_hidden.dat` only contains the userID and restaurantID and not the ratings. Finally, you will be making predictions for these restaurants, user pairs and will be submitting your predictions to the Kaggle competition. We will then evaluate your predictions against the actual ratings and you will be ranked on the leaderboard accordingly.

# %% [markdown]
# ## Task 1: Implement get_sparse_mat function (2 marks)
#
# Before we start building our model, we first need to get our data in a suitable form which can be fed to the network. The input to the network will be a vector of size 5138 (number of restaurants) for each user, where each element of the vector will contain the rating of the restaurant whose id matches with the index of that element. If the user has not rated a particular restaurant, the element corresponding to that will be set to zero.
#
# For example: If a user has only rated the restaurants with ids 3, 19 and 1009 as 2, 4 and 3.5 respectively, then the feature vector for that user will be a 5138 sized array containing 2 in the index 3, 4 in the index 19, 3.5 in index 1009 and zero everywhere else.
#
# Hence our full dataset will be a matrix of size 3579 X 5138 (number of users X number of restaurants).
#
# Since we know that the users have reviewed only a small portion of all 5138 restaurants, the data matrix will be very sparse (will mostly contain zeros). Hence it does not make sense to store the whole 3579 X 5138 matrix in memory. Instead, we create a sparse matrix where for each user we store the tuples containing the restaurant id and the rating for that restaurant.
#
# For example: In the previous example where we had a user who rated restaurants 3, 19 and 1009 only, we will store the tuples [(3, 2), (19, 4), (1009, 3.5)]. Earlier we store an array of size 5138 elements for the user but now we need to have an array containing 3 elements, saving much memory. While feeding the inputs to the neural net we convert this sparse representation to the full 5138-dimensional vector.
#
# The function `get_sparse_mat` takes as the input the filename string which can either be `train.dat` and `test.dat` and constructs a sparse matrix containing the list of tuples for each user as we described above. The output of the function should be a python list of size 3579 with each element being a list of tuples.
#
# ![alt text](get_sparse_mat.png)
#
# **Note 1:** You can read .dat files similar to how you read .txt files. Use python's inbuilt function *open* to create a file pointer lets say *fp*, then you can use functions like read, readline etc. to read the data values from the file. Refer to this [link](https://www.programiz.com/python-programming/file-operation) if you want a refresher to file IO in python.
#
# **Note 2:** You can also read .dat files using pandas similar to the way you read CSV files using *pd.read_csv* function.
#
# **Note 3:** The tuples in the list (restaurantID, rating) should have restaurantID as an integer value and rating as a float.

# %%
def get_sparse_mat(filename):
  
    '''
    
    Inputs: 
        -filename: a string containing the name of the file from which we want
                    to extract the data. In our case it can be either train.dat
                    or test.dat
                    
    Returns a python list of size 3579 (number of users) with each element of
    the list being a list of tuples (restaurantID, rating).
    
    '''
    
    data = pd.read_table(filename, sep=',', names=['index', '1', '2'], )
    sparse_mat = []
    for i in range(0, NUM_USERS):
        collect = data.loc[data['index'] == i]
        collect = collect.drop(['index'], axis=1)
        a = collect['1'].values.tolist()
        b = collect['2'].values.tolist()
        c = []
        for j in range(0, len(a)):
            c.append([a[j], b[j]])
        sparse_mat.append(c)


    
    return sparse_mat

# %%
#Now that we have implemented the get_sparse_mat function we can get the train and test sparse matrices
train_smat = get_sparse_mat(OUTPUT_DIR_TRAIN)
test_smat = get_sparse_mat(OUTPUT_DIR_TEST)

# %%
                            """Don't change code in this cell"""
#SAMPLE TEST CASE
print("Running Sample Test Case 1")
assert np.allclose(len(train_smat), 3579)
print("Sample Test Case 1 Passed")
print("Running Sample Test Case 2")
assert np.allclose(len(test_smat), 3579)
print("Sample Test Case 2 Passed")
print("Running Sample Test Case 3")
assert np.allclose(len(train_smat[5]), 234)
print("Sample Test Case 3 Passed")
print("Running Sample Test Case 4")
assert np.allclose(train_smat[5][:5],[(626, 4.0), (1177, 4.5), (976, 4.0), (3926, 4.0), (3274, 5.0)])
print("Sample Test Case 4 Passed")
print("Running Sample Test Case 5")
assert np.allclose(len(test_smat[5]),5)
print("Sample Test Case 5 Passed")
print("Running Sample Test Case 6")
assert np.allclose(test_smat[5][:5], [(574, 3.5), (3717, 4.0), (2303, 4.0), (863, 3.5), (1706, 1.0)])
print("Sample Test Case 6 Passed")
print("Running Sample Test Case 7")
assert ((type(train_smat[5][:5][0][0]) is int) and (type(train_smat[5][:5][0][1]) is float))
print("Sample Test Case 7 Passed")
print("Running Sample Test Case 8")
assert ((type(test_smat[5][:5][0][0]) is int) and (type(test_smat[5][:5][0][1]) is float))
print("Sample Test Case 8 Passed")
# Out:
# Running Sample Test Case 1
# Sample Test Case 1 Passed
# Running Sample Test Case 2
# Sample Test Case 2 Passed
# Running Sample Test Case 3
# Sample Test Case 3 Passed
# Running Sample Test Case 4
# Sample Test Case 4 Passed
# Running Sample Test Case 5
# Sample Test Case 5 Passed
# Running Sample Test Case 6
# Sample Test Case 6 Passed
# Running Sample Test Case 7
# Sample Test Case 7 Passed
# Running Sample Test Case 8
# Sample Test Case 8 Passed

# %%
                            """Don't change code in this cell"""
#HIDDEN TEST CASE
# Out:
# "Don't change code in this cell"

# %% [markdown]
# ## Dataloaders
#
# Next we have defined a dataset class which can be used to efficiently iterate through the dataset. We have provided its implementation for you. Go through it once and make sure you understand it. Using the dataset objects we define data generators for train and test sets which are used to get batches of input data. To learn about how pytorch's Dataset and Dataloader classes work in detail please go through this link: https://stanford.edu/~shervine/blog/pytorch-how-to-generate-data-parallel

# %%
class Dataset(data.Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        X_sam = torch.zeros(5138)
        y_sam = torch.zeros(5138)
        for i in range(len(self.X[index])):
            X_sam[self.X[index][i][0]] = self.X[index][i][1]

        for i in range(len(self.y[index])):
            y_sam[self.y[index][i][0]] = self.y[index][i][1]

        return X_sam, y_sam

# %%
train_dataset = Dataset(train_smat,train_smat)
test_dataset = Dataset(train_smat, test_smat)

# %%
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 6 if platform == 'linux' else 0}
training_generator = data.DataLoader(train_dataset, **params)# sampler = torch.utils.data.SequentialSampler(train_dataset))
validation_generator = data.DataLoader(test_dataset, **params)# sampler = torch.utils.data.SequentialSampler(train_dataset))

# %% [markdown]
# ## Implementing Autoencoder Architecture
#
# Now that we have our datasets ready we can define the architecture of our autoencoder network. We typically define a network architecture in pytorch by extending the nn.Module class. In the cell below we have demonstrated how you can implement a 3 layer neural network with the following architecture in pytorch.
#
# INPUT(size = 100) -> FC+ReLU(size = 64) -> FC+ReLU(size = 32) -> FC(size = 10)

# %%
class threeLayerNet(nn.Module):
    
    def __init__(self):
        '''
        In constructor we define different layers we will use in our architecture.
        '''
        #Constructor call to the superclass
        super(threeLayerNet, self).__init__()
        #Defining the layers to be used in the network. 
        #nn.Linear defines a fully connected layer and the first argument represents the input size and the second represents the output size.
        self.layer1 = nn.Linear(100, 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 10)
        #Defining the activation function to be used in the network
        self.act = nn.ReLU()
        
    def forward(self, x):
        
        '''
        The forward function takes passes the input through the layers and returns the output.
        Inputs:
            -x : Input tensor of shape [N_batch, 100]
            
        Returns the output of neural network of shape [N_batch, 10]
        '''
        
        out = self.layer1(x)
        out = self.act(out)
        out = self.layer2(out)
        out = self.act(out)
        out = self.layer3(out)
        
        return out

# %%
#Once we have defined the network class we can create an instance for it.
net = threeLayerNet()

#To get the output of the network on data just call the network instance and feed the inputs

x = torch.rand(5, 100) #Just a random input
network_prediction = net(x)
network_prediction
# Out:
# tensor([[ 0.0429, -0.1079,  0.2100, -0.0437,  0.0598,  0.0489,  0.2232, -0.1854,
#          -0.1493, -0.0353],
#         [ 0.0209, -0.1134,  0.1992, -0.0460,  0.0336,  0.0557,  0.2156, -0.1789,
#          -0.1579, -0.0424],
#         [-0.0055, -0.0234,  0.2274, -0.0016,  0.0654,  0.1145,  0.1840, -0.1787,
#          -0.1968, -0.0328],
#         [-0.0006, -0.0704,  0.2185, -0.0284,  0.0471,  0.0895,  0.2083, -0.1359,
#          -0.1475, -0.0158],
#         [ 0.0019, -0.0558,  0.2171, -0.0243,  0.0607,  0.1144,  0.2093, -0.1387,
#          -0.1523, -0.0283]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Task 2.1 Warmup Excercise: Implement a toy neural network. (1 Mark)
#
# Before you implement the autoencoder architecture as a practice implement a simple 2 layer neural with the following architecture:
#
# INPUT(size = 224) -> FC+ReLU(size = 128) -> FC+tanh(size = 5)

# %%
class twolayerNet(nn.Module):
    
    def __init__(self):
        '''
        Define the layers and activation functions to be used in the network.
        '''
        super(twolayerNet, self).__init__()
        self.layer1 = nn.Linear(224, 128)
        self.layer2 = nn.Linear(128, 5)
        self.act_1 = nn.ReLU()
        self.act_2 = nn.Tanh()
     
    def forward(self, x):
        
        '''
        Implement the forward function which takes as input the tensor x and feeds it to the layers of the network
        and returns the output.
        
        Inputs:
            -x : Input tensor of shape [N_batch, 224]
            
        Returns the output of neural network of shape [N_batch, 5]
        '''
        
        out = torch.zeros(x.shape[0], 5)
        out = self.layer1(x)
        out = self.act_1(out)
        out = self.layer2(out)
        out = self.act_2(out)
        
        return out

# %%
net = twolayerNet()

# %%
                            """Don't change code in this cell"""
    
### SAMPLE TEST CASE
params_shapes = [p.shape for p in net.parameters()]
params_shapes = sorted(params_shapes)
print("Running Sample Test Case")
assert params_shapes ==[torch.Size([5]),
 torch.Size([5, 128]),
 torch.Size([128]),
 torch.Size([128, 224])]
print("Sample Test Case Passed")
# Out:
# Running Sample Test Case
# Sample Test Case Passed

# %%
                            """Don't change code in this cell"""
    
### HIDDEN TEST CASE
# Out:
# "Don't change code in this cell"

# %% [markdown]
# ## Task 2.2: Implement the deep autoencoder (2.5 Marks)
#
# Now you will implement the autoencoder network which we will be using to build our recommendation system. The architeture of the network should be:
#
# INPUT(size = 5138) -> FC+Tanh(size = 32) -> FC(size = 5138);

# %%
class DAE(nn.Module):
    def __init__(self):
        '''
        Define the layers and activation functions to be used in the network.
        '''
        super(DAE, self).__init__()
        self.layer_1 = nn.Linear(5138, 32)
        self.layer_2 = nn.Linear(32, 5138)
        self.act = nn.Tanh()
        
    def forward(self, x):
        '''
        Implement the forward function which takes as input the tensor x and feeds it to the layers of the network
        and returns the output.
        
        Inputs:
            -x : Input tensor of shape [N_batch, 5138]
            
        Returns the output of neural network of shape [N_batch, 5138]
        '''
        
        out = torch.zeros(x.shape[0], 5138)
        out = self.layer_1(x)
        out = self.act(out)
        out = self.layer_2(out)

        return out

# %%
net = DAE()

# %%
                            """Don't change code in this cell"""
    
### SAMPLE TEST CASE
params_shapes = [p.shape for p in net.parameters()]
params_shapes = sorted(params_shapes)
print("Running Sample Test Case")
assert params_shapes == [torch.Size([32]), torch.Size([32, 5138]), torch.Size([5138]), torch.Size([5138, 32])]
print("Sample Test Case Passed")
# Out:
# Running Sample Test Case
# Sample Test Case Passed

# %%
                            """Don't change code in this cell"""
### HIDDEN TEST CASE
# Out:
# "Don't change code in this cell"

# %% [markdown]
# ## Task 3: Implement the loss function (2.5 Marks)
#
# Now that we have defined our autoencoder network we need to define a loss function to train our model. We will be using mean squared error as our loss function which can be simply implemented by taking the squared sum of the errors between the model predictions and the labels and dividing it by the number of training examples. However, there is a small catch here. As we described in the beginning, for a user we have to compute this error for the restaurants whose ratings have been given by the user and not for the restaurants with the missing ratings.
#
# ![loss.png](loss.png)
#
# Please note that in the figure we are dividing the sum of squared errors with 4 which comes from the total number of ratings that are available in the input data.
#
# The function masked_loss takes as the input predictions and labels and calculates the mean squared error for the available ratings. One way of doing this is to first define a mask which is zero for the ratings not available and one for the available ones. Then we multiply this mask with the model predictions so that it zeros out the predictions of the network which are missing in the input data. Now we can calculate the sum of squared errors between the masked predictions and the input ratings and divide it with the number of available ratings which can be calculated by counting the number of ones in the mask.
#
# ![maskedloss1.png](maskedloss1.png)
# ![maskedloss2.png](maskedloss2.png)
# ![maskedloss3.png](maskedloss3.png)
#
# Hint: You might find torch.where function useful in creating the mask.

# %%
def masked_loss(preds, labels):
    
    '''
    Inputs:
        -preds: Model predictions [N_batch, 5138]
        -labels: User ratings [N_batch, 5138]
        
    Returns the masked loss as described above.
    '''
    ones = torch.ones_like(preds)
    zeros = torch.zeros_like(preds)
    mask = torch.where(labels == zeros, zeros, ones)
    layer_apply = mask*preds
    loss_mat = (layer_apply-labels)**2
    loss = (torch.sum(loss_mat))/(torch.nonzero(loss_mat).size(0))
    return loss

# %%
                            """Don't change code in this cell"""
    
### SAMPLE TEST CASE
x = torch.zeros(3, 5138)
x[0][100] = 1
x[0][7] = 1
x[0][1009] = 1
x[1][101] = 1
x[1][8] = 1
x[1][1010] = 1
x[1][56] = 1
x[2][102] = 1
x[2][9] = 1
loss = masked_loss(net(x), x).item()
print("Running Sample Test Case")
assert np.allclose(loss, 1.1857765913009644, atol = 1e-4)
print("Sample Test Case Passed")
# Out:
# Running Sample Test Case
# Sample Test Case Passed

# %%
                            """Don't change code in this cell"""
    
### HIDDEN TEST CASE
# Out:
# "Don't change code in this cell"

# %% [markdown]
# ## Defining the Optimizer
#
# Now that we have our autoencoder architecture and loss function ready we only need to define an optimizer object before we begin training. We will be using Stochastic Gradient Descent (SGD) optimizer with a learning rate of 0.1. Pytorch comes with optim module which contains different optimizers for optimizing neural nets. We can define an instance of an optimizer as:
# optim.OptimizerName(net.parameters(), learning_rate), where the first argument corresponds to the list of parameters of the network and the second parameter being the learning rate. We have defined SGD optimizer object in the cell below.

# %%
opti = optim.SGD(net.parameters(), lr=0.1)

# %% [markdown]
# ## Task 4: Training the model (2 marks)
#
# Now we have everything ready to start training our model. Each iteration will consist of 4 important steps:
#
# 1. Feeding input data to the network and obtaining model predictions
# 2. Compute the loss between inputs and labels say *loss*
# 3. Backpropagate the gradients using *loss.backward()*
# 4. Take the optimization step using the *step* method of the optimizer instance.
#
# This function will be manually graded since there the training results might vary each time we run the network. Effectively you should see a decrease in both train and validation losses. The final training loss should be around 1.7 and validation loss should be around 2 to 2.2 towards the end.

# %%
def train(net, criterion, opti, training_generator, validation_generator, max_epochs = 10):
    
    '''
    Inputs:
        - net: The model instance
        - criterion: Loss function, in our case it is masked_loss function.
        - opti: Optimizer Instance
        - training_generator: For iterating through the training set
        - validation_generator: For iterating through the test set
        - max_epochs: Number of training epochs. One epoch is defined as one complete presentation of the data set.
    
    Outputs:
        - train_losses: a list of size max_epochs containing the average loss for each epoch of training set.
        - val_losses: a list of size max_epochs containing the average loss for each epoch of test set.
        
        Note: We compute the average loss in an epoch by summing the loss at each iteration of that epoch
        and then dividing the sum by the number of iterations in that epoch.
    '''

    train_losses = []
    val_losses = []
    
    for epoch in range(max_epochs):
        running_loss = 0 #Accumulate the loss in each iteration of the epoch in this variable
        cnt = 0 #Increment it each time to find the number iterations in the epoch.
        # Training iterations
        for batch_X, batch_y in training_generator:
            opti.zero_grad() #Clears the gradients of all variables.
            preds = net(batch_X)
            loss = masked_loss(preds, batch_y)
            running_loss = running_loss+loss.item()
            loss.backward()
            opti.step()
            cnt = cnt+1

        print("Epoch {}: Training Loss {}".format(epoch+1, running_loss/cnt))
        train_losses.append(running_loss/cnt)
        
        
        #Now that we have trained the model for an epoch, we evaluate it on the test set
        running_loss = 0
        cnt = 0
        with torch.set_grad_enabled(False):
            for batch_X, batch_y in validation_generator:
                opti.zero_grad() #Clears the gradients of all variables.
                preds = net(batch_X)
                running_loss = running_loss+loss.item()
                loss = masked_loss(preds, batch_y)
                cnt = cnt+1
                
        print("Epoch {}: Validation Loss {}".format(epoch+1, running_loss/cnt))

        val_losses.append(running_loss/cnt)
        
    return train_losses, val_losses

# %%
net = DAE()
opti = optim.SGD(net.parameters(), lr = 1e-1)
train_losses, val_losses = train(net, masked_loss, opti, training_generator, validation_generator, 20)
# Out:
# tensor(16.3633, grad_fn=<DivBackward0>)
# tensor(15.4717, grad_fn=<DivBackward0>)
# tensor(16.7751, grad_fn=<DivBackward0>)
# tensor(16.5517, grad_fn=<DivBackward0>)
# tensor(15.7211, grad_fn=<DivBackward0>)
# tensor(16.5930, grad_fn=<DivBackward0>)
# tensor(15.6021, grad_fn=<DivBackward0>)
# tensor(15.2017, grad_fn=<DivBackward0>)
# tensor(16.6441, grad_fn=<DivBackward0>)
# tensor(16.4137, grad_fn=<DivBackward0>)
# tensor(15.1969, grad_fn=<DivBackward0>)
# tensor(15.3731, grad_fn=<DivBackward0>)
# tensor(15.9782, grad_fn=<DivBackward0>)
# tensor(15.9580, grad_fn=<DivBackward0>)
# tensor(15.5905, grad_fn=<DivBackward0>)
# tensor(15.9984, grad_fn=<DivBackward0>)
# tensor(15.7966, grad_fn=<DivBackward0>)
# tensor(15.4714, grad_fn=<DivBackward0>)
# tensor(15.3436, grad_fn=<DivBackward0>)
# tensor(14.7126, grad_fn=<DivBackward0>)
# tensor(14.9625, grad_fn=<DivBackward0>)
# tensor(15.1182, grad_fn=<DivBackward0>)
# tensor(15.4844, grad_fn=<DivBackward0>)
# tensor(14.0603, grad_fn=<DivBackward0>)
# tensor(15.1496, grad_fn=<DivBackward0>)
# tensor(15.1604, grad_fn=<DivBackward0>)
# tensor(15.1963, grad_fn=<DivBackward0>)
# tensor(14.8494, grad_fn=<DivBackward0>)
# tensor(13.9265, grad_fn=<DivBackward0>)
# tensor(14.9484, grad_fn=<DivBackward0>)
# tensor(14.2730, grad_fn=<DivBackward0>)
# tensor(14.5618, grad_fn=<DivBackward0>)
# tensor(14.1266, grad_fn=<DivBackward0>)
# tensor(14.3231, grad_fn=<DivBackward0>)
# tensor(13.8499, grad_fn=<DivBackward0>)
# tensor(13.7870, grad_fn=<DivBackward0>)
# tensor(14.6719, grad_fn=<DivBackward0>)
# tensor(14.2809, grad_fn=<DivBackward0>)
# tensor(14.3288, grad_fn=<DivBackward0>)
# tensor(13.7021, grad_fn=<DivBackward0>)
# tensor(13.5510, grad_fn=<DivBackward0>)
# tensor(14.0530, grad_fn=<DivBackward0>)
# tensor(14.2285, grad_fn=<DivBackward0>)
# tensor(14.1662, grad_fn=<DivBackward0>)
# tensor(13.3160, grad_fn=<DivBackward0>)
# tensor(14.2968, grad_fn=<DivBackward0>)
# tensor(13.2054, grad_fn=<DivBackward0>)
# tensor(13.4909, grad_fn=<DivBackward0>)
# tensor(13.1770, grad_fn=<DivBackward0>)
# tensor(13.5379, grad_fn=<DivBackward0>)
# tensor(13.2284, grad_fn=<DivBackward0>)
# tensor(12.3893, grad_fn=<DivBackward0>)
# tensor(12.6169, grad_fn=<DivBackward0>)
# tensor(13.3052, grad_fn=<DivBackward0>)
# tensor(13.3047, grad_fn=<DivBackward0>)
# tensor(13.4123, grad_fn=<DivBackward0>)
# Epoch 1: Training Loss 14.69280663558415
# tensor(13.9343)
# tensor(14.0351)
# tensor(12.2783)
# tensor(13.2462)
# tensor(13.2378)
# tensor(12.8721)
# tensor(14.1682)
# tensor(13.6197)
# tensor(14.2917)
# tensor(12.2505)
# tensor(13.3716)
# tensor(13.3285)
# tensor(12.9269)
# tensor(13.3302)
# tensor(14.2253)
# tensor(14.1803)
# tensor(14.0773)
# tensor(13.2620)
# tensor(13.1418)
# tensor(12.7231)
# tensor(13.0182)
# tensor(13.6688)
# tensor(13.4354)
# tensor(13.3601)
# tensor(12.8368)
# tensor(13.5114)
# tensor(13.8210)
# tensor(13.4736)
# tensor(13.5011)
# tensor(12.8433)
# tensor(12.2621)
# tensor(13.1198)
# tensor(13.5114)
# tensor(13.9854)
# tensor(13.3331)
# tensor(13.7688)
# tensor(12.7611)
# tensor(13.3480)
# tensor(12.5141)
# tensor(13.1703)
# tensor(12.9677)
# tensor(13.4011)
# tensor(13.3561)
# tensor(13.4904)
# tensor(13.0763)
# tensor(13.1400)
# tensor(13.4541)
# tensor(13.7535)
# tensor(13.8646)
# tensor(12.7353)
# tensor(14.2023)
# tensor(13.0237)
# tensor(13.5505)
# tensor(13.3349)
# tensor(13.6223)
# tensor(13.3939)
# Epoch 1: Validation Loss 13.35946353844234
# tensor(13.0217, grad_fn=<DivBackward0>)
# tensor(12.2843, grad_fn=<DivBackward0>)
# tensor(12.7382, grad_fn=<DivBackward0>)
# tensor(13.4068, grad_fn=<DivBackward0>)
# tensor(12.4068, grad_fn=<DivBackward0>)
# tensor(12.8082, grad_fn=<DivBackward0>)
# tensor(11.9767, grad_fn=<DivBackward0>)
# tensor(12.0693, grad_fn=<DivBackward0>)
# tensor(12.8231, grad_fn=<DivBackward0>)
# tensor(12.3213, grad_fn=<DivBackward0>)
# tensor(11.8519, grad_fn=<DivBackward0>)
# tensor(12.7278, grad_fn=<DivBackward0>)
# tensor(12.4557, grad_fn=<DivBackward0>)
# tensor(12.1623, grad_fn=<DivBackward0>)
# tensor(12.7285, grad_fn=<DivBackward0>)
# tensor(11.9109, grad_fn=<DivBackward0>)
# tensor(11.8606, grad_fn=<DivBackward0>)
# tensor(12.5167, grad_fn=<DivBackward0>)
# tensor(11.6178, grad_fn=<DivBackward0>)
# tensor(11.5662, grad_fn=<DivBackward0>)
# tensor(11.7564, grad_fn=<DivBackward0>)
# tensor(11.8998, grad_fn=<DivBackward0>)
# tensor(11.4190, grad_fn=<DivBackward0>)
# tensor(12.2680, grad_fn=<DivBackward0>)
# tensor(11.8850, grad_fn=<DivBackward0>)
# tensor(11.0235, grad_fn=<DivBackward0>)
# tensor(11.3891, grad_fn=<DivBackward0>)
# tensor(11.0987, grad_fn=<DivBackward0>)
# tensor(11.2166, grad_fn=<DivBackward0>)
# tensor(11.7034, grad_fn=<DivBackward0>)
# tensor(11.3478, grad_fn=<DivBackward0>)
# tensor(11.4277, grad_fn=<DivBackward0>)
# tensor(11.4309, grad_fn=<DivBackward0>)
# tensor(11.4231, grad_fn=<DivBackward0>)
# tensor(11.0192, grad_fn=<DivBackward0>)
# tensor(10.6003, grad_fn=<DivBackward0>)
# tensor(11.2309, grad_fn=<DivBackward0>)
# tensor(11.0681, grad_fn=<DivBackward0>)
# tensor(10.9509, grad_fn=<DivBackward0>)
# tensor(11.3451, grad_fn=<DivBackward0>)
# tensor(10.7423, grad_fn=<DivBackward0>)
# tensor(10.5909, grad_fn=<DivBackward0>)
# tensor(11.2898, grad_fn=<DivBackward0>)
# tensor(10.6001, grad_fn=<DivBackward0>)
# tensor(10.3276, grad_fn=<DivBackward0>)
# tensor(10.2991, grad_fn=<DivBackward0>)
# tensor(10.4580, grad_fn=<DivBackward0>)
# tensor(10.5457, grad_fn=<DivBackward0>)
# tensor(10.1736, grad_fn=<DivBackward0>)
# tensor(10.4437, grad_fn=<DivBackward0>)
# tensor(10.0789, grad_fn=<DivBackward0>)
# tensor(9.8573, grad_fn=<DivBackward0>)
# tensor(10.6081, grad_fn=<DivBackward0>)
# tensor(10.2818, grad_fn=<DivBackward0>)
# tensor(9.8674, grad_fn=<DivBackward0>)
# tensor(10.0064, grad_fn=<DivBackward0>)
# Epoch 2: Training Loss 11.44516020161765
# tensor(9.3591)
# tensor(10.8415)
# tensor(10.9040)
# tensor(10.0568)
# tensor(10.6749)
# tensor(10.5954)
# tensor(10.2641)
# tensor(10.2976)
# tensor(10.6342)
# tensor(10.8774)
# tensor(10.7623)
# tensor(11.0097)
# tensor(10.4448)
# tensor(10.7290)
# tensor(9.9557)
# tensor(9.7208)
# tensor(10.1062)
# tensor(9.8850)
# tensor(11.0327)
# tensor(10.7754)
# tensor(10.7395)
# tensor(10.9682)
# tensor(10.6877)
# tensor(10.4436)
# tensor(10.4024)
# tensor(10.2177)
# tensor(10.4503)
# tensor(10.7617)
# tensor(9.6985)
# tensor(11.0301)
# tensor(10.2240)
# tensor(11.2391)
# tensor(9.9678)
# tensor(9.6213)
# tensor(9.9017)
# tensor(10.6597)
# tensor(10.3208)
# tensor(10.5256)
# tensor(11.0390)
# tensor(10.6467)
# tensor(10.3530)
# tensor(10.5383)
# tensor(11.5178)
# tensor(11.1533)
# tensor(10.4194)
# tensor(10.1901)
# tensor(10.5792)
# tensor(10.6116)
# tensor(10.4987)
# tensor(10.5525)
# tensor(10.1514)
# tensor(10.3745)
# tensor(10.8850)
# tensor(10.5778)
# tensor(10.2579)
# tensor(10.0260)
# Epoch 2: Validation Loss 10.48461653505053
# tensor(9.3578, grad_fn=<DivBackward0>)
# tensor(9.6719, grad_fn=<DivBackward0>)
# tensor(9.8191, grad_fn=<DivBackward0>)
# tensor(9.7438, grad_fn=<DivBackward0>)
# tensor(9.9538, grad_fn=<DivBackward0>)
# tensor(9.2992, grad_fn=<DivBackward0>)
# tensor(9.6997, grad_fn=<DivBackward0>)
# tensor(9.7682, grad_fn=<DivBackward0>)
# tensor(9.4554, grad_fn=<DivBackward0>)
# tensor(9.4220, grad_fn=<DivBackward0>)
# tensor(8.9557, grad_fn=<DivBackward0>)
# tensor(9.5927, grad_fn=<DivBackward0>)
# tensor(9.2150, grad_fn=<DivBackward0>)
# tensor(9.3752, grad_fn=<DivBackward0>)
# tensor(9.2515, grad_fn=<DivBackward0>)
# tensor(9.8441, grad_fn=<DivBackward0>)
# tensor(9.4838, grad_fn=<DivBackward0>)
# tensor(9.4830, grad_fn=<DivBackward0>)
# tensor(9.6271, grad_fn=<DivBackward0>)
# tensor(9.3163, grad_fn=<DivBackward0>)
# tensor(9.8513, grad_fn=<DivBackward0>)
# tensor(9.1810, grad_fn=<DivBackward0>)
# tensor(9.7750, grad_fn=<DivBackward0>)
# tensor(9.0673, grad_fn=<DivBackward0>)
# tensor(9.4134, grad_fn=<DivBackward0>)
# tensor(9.1983, grad_fn=<DivBackward0>)
# tensor(8.9814, grad_fn=<DivBackward0>)
# tensor(9.0129, grad_fn=<DivBackward0>)
# tensor(9.2712, grad_fn=<DivBackward0>)
# tensor(9.2406, grad_fn=<DivBackward0>)
# tensor(8.8717, grad_fn=<DivBackward0>)
# tensor(8.8981, grad_fn=<DivBackward0>)
# tensor(9.3638, grad_fn=<DivBackward0>)
# tensor(8.2334, grad_fn=<DivBackward0>)
# tensor(9.1823, grad_fn=<DivBackward0>)
# tensor(8.7219, grad_fn=<DivBackward0>)
# tensor(8.8818, grad_fn=<DivBackward0>)
# tensor(9.1813, grad_fn=<DivBackward0>)
# tensor(8.7831, grad_fn=<DivBackward0>)
# tensor(8.2593, grad_fn=<DivBackward0>)
# tensor(8.4092, grad_fn=<DivBackward0>)
# tensor(8.6337, grad_fn=<DivBackward0>)
# tensor(8.8625, grad_fn=<DivBackward0>)
# tensor(8.3454, grad_fn=<DivBackward0>)
# tensor(8.2036, grad_fn=<DivBackward0>)
# tensor(8.1768, grad_fn=<DivBackward0>)
# tensor(8.1312, grad_fn=<DivBackward0>)
# tensor(8.7214, grad_fn=<DivBackward0>)
# tensor(8.0815, grad_fn=<DivBackward0>)
# tensor(8.5127, grad_fn=<DivBackward0>)
# tensor(7.9005, grad_fn=<DivBackward0>)
# tensor(8.2479, grad_fn=<DivBackward0>)
# tensor(8.4426, grad_fn=<DivBackward0>)
# tensor(8.2819, grad_fn=<DivBackward0>)
# tensor(8.7061, grad_fn=<DivBackward0>)
# tensor(7.8643, grad_fn=<DivBackward0>)
# Epoch 3: Training Loss 9.021888392312187
# tensor(8.7410)
# tensor(8.3965)
# tensor(8.1053)
# tensor(8.7490)
# tensor(8.6205)
# tensor(8.3910)
# tensor(9.1181)
# tensor(8.1645)
# tensor(7.8910)
# tensor(8.9049)
# tensor(8.9861)
# tensor(7.9556)
# tensor(8.5143)
# tensor(8.4409)
# tensor(8.9586)
# tensor(9.0965)
# tensor(8.6625)
# tensor(8.8880)
# tensor(8.4586)
# tensor(8.8325)
# tensor(8.2553)
# tensor(8.1862)
# tensor(8.0327)
# tensor(8.9969)
# tensor(8.8643)
# tensor(7.9263)
# tensor(8.5320)
# tensor(8.1300)
# tensor(7.8830)
# tensor(8.0812)
# tensor(8.4584)
# tensor(8.5165)
# tensor(8.2960)
# tensor(8.6403)
# tensor(8.1339)
# tensor(9.0758)
# tensor(8.8855)
# tensor(8.5545)
# tensor(8.2403)
# tensor(8.3183)
# tensor(8.2420)
# tensor(7.9720)
# tensor(8.1704)
# tensor(7.6868)
# tensor(8.0013)
# tensor(8.5394)
# tensor(8.4554)
# tensor(9.5622)
# tensor(9.2459)
# tensor(8.0994)
# tensor(7.4686)
# tensor(8.3247)
# tensor(9.1631)
# tensor(8.4438)
# tensor(8.3865)
# tensor(9.1493)
# Epoch 3: Validation Loss 8.455505652087075
# tensor(8.1821, grad_fn=<DivBackward0>)
# tensor(8.3334, grad_fn=<DivBackward0>)
# tensor(8.2735, grad_fn=<DivBackward0>)
# tensor(8.2772, grad_fn=<DivBackward0>)
# tensor(7.9056, grad_fn=<DivBackward0>)
# tensor(8.4377, grad_fn=<DivBackward0>)
# tensor(8.2467, grad_fn=<DivBackward0>)
# tensor(7.5627, grad_fn=<DivBackward0>)
# tensor(7.6348, grad_fn=<DivBackward0>)
# tensor(7.5497, grad_fn=<DivBackward0>)
# tensor(7.6486, grad_fn=<DivBackward0>)
# tensor(7.5100, grad_fn=<DivBackward0>)
# tensor(7.7407, grad_fn=<DivBackward0>)
# tensor(8.2495, grad_fn=<DivBackward0>)
# tensor(7.2942, grad_fn=<DivBackward0>)
# tensor(7.6004, grad_fn=<DivBackward0>)
# tensor(7.9000, grad_fn=<DivBackward0>)
# tensor(7.7490, grad_fn=<DivBackward0>)
# tensor(7.5268, grad_fn=<DivBackward0>)
# tensor(7.1552, grad_fn=<DivBackward0>)
# tensor(7.6473, grad_fn=<DivBackward0>)
# tensor(7.3470, grad_fn=<DivBackward0>)
# tensor(7.5762, grad_fn=<DivBackward0>)
# tensor(7.5607, grad_fn=<DivBackward0>)
# tensor(7.3825, grad_fn=<DivBackward0>)
# tensor(7.5196, grad_fn=<DivBackward0>)
# tensor(7.2801, grad_fn=<DivBackward0>)
# tensor(6.9469, grad_fn=<DivBackward0>)
# tensor(7.0615, grad_fn=<DivBackward0>)
# tensor(7.5301, grad_fn=<DivBackward0>)
# tensor(7.3920, grad_fn=<DivBackward0>)
# tensor(7.6137, grad_fn=<DivBackward0>)
# tensor(7.6182, grad_fn=<DivBackward0>)
# tensor(7.2952, grad_fn=<DivBackward0>)
# tensor(6.8467, grad_fn=<DivBackward0>)
# tensor(6.9380, grad_fn=<DivBackward0>)
# tensor(7.8027, grad_fn=<DivBackward0>)
# tensor(7.3656, grad_fn=<DivBackward0>)
# tensor(7.2842, grad_fn=<DivBackward0>)
# tensor(7.2499, grad_fn=<DivBackward0>)
# tensor(6.6675, grad_fn=<DivBackward0>)
# tensor(6.7651, grad_fn=<DivBackward0>)
# tensor(7.5711, grad_fn=<DivBackward0>)
# tensor(7.1512, grad_fn=<DivBackward0>)
# tensor(6.9320, grad_fn=<DivBackward0>)
# tensor(6.5938, grad_fn=<DivBackward0>)
# tensor(6.9648, grad_fn=<DivBackward0>)
# tensor(6.5368, grad_fn=<DivBackward0>)
# tensor(6.7082, grad_fn=<DivBackward0>)
# tensor(7.0166, grad_fn=<DivBackward0>)
# tensor(6.2330, grad_fn=<DivBackward0>)
# tensor(6.3408, grad_fn=<DivBackward0>)
# tensor(6.1265, grad_fn=<DivBackward0>)
# tensor(6.7783, grad_fn=<DivBackward0>)
# tensor(6.6804, grad_fn=<DivBackward0>)
# tensor(6.9921, grad_fn=<DivBackward0>)
# Epoch 4: Training Loss 7.358828042234693
# tensor(7.2778)
# tensor(7.0170)
# tensor(6.5913)
# tensor(6.8181)
# tensor(7.3902)
# tensor(7.1250)
# tensor(7.0092)
# tensor(6.5780)
# tensor(6.5895)
# tensor(6.5932)
# tensor(7.5660)
# tensor(7.6281)
# tensor(6.6724)
# tensor(6.1985)
# tensor(7.1842)
# tensor(7.3044)
# tensor(6.6000)
# tensor(7.4106)
# tensor(6.7802)
# tensor(6.5481)
# tensor(6.6668)
# tensor(6.9633)
# tensor(7.3008)
# tensor(7.9107)
# tensor(7.4158)
# tensor(7.4145)
# tensor(7.2888)
# tensor(7.2012)
# tensor(6.9868)
# tensor(6.6715)
# tensor(7.1345)
# tensor(7.1015)
# tensor(6.9476)
# tensor(7.3754)
# tensor(6.1832)
# tensor(7.0819)
# tensor(7.5064)
# tensor(7.2773)
# tensor(7.2069)
# tensor(7.9990)
# tensor(5.8219)
# tensor(7.4272)
# tensor(7.7226)
# tensor(7.2160)
# tensor(6.5605)
# tensor(7.7773)
# tensor(7.4095)
# tensor(6.7471)
# tensor(7.7625)
# tensor(6.9405)
# tensor(7.0798)
# tensor(6.4846)
# tensor(7.5899)
# tensor(6.7652)
# tensor(7.2032)
# tensor(7.6010)
# Epoch 4: Validation Loss 7.071704285485404
# tensor(7.1907, grad_fn=<DivBackward0>)
# tensor(6.5814, grad_fn=<DivBackward0>)
# tensor(6.6167, grad_fn=<DivBackward0>)
# tensor(6.4190, grad_fn=<DivBackward0>)
# tensor(6.5764, grad_fn=<DivBackward0>)
# tensor(6.6939, grad_fn=<DivBackward0>)
# tensor(6.8619, grad_fn=<DivBackward0>)
# tensor(6.9324, grad_fn=<DivBackward0>)
# tensor(6.5773, grad_fn=<DivBackward0>)
# tensor(6.8204, grad_fn=<DivBackward0>)
# tensor(6.5819, grad_fn=<DivBackward0>)
# tensor(6.2885, grad_fn=<DivBackward0>)
# tensor(6.5995, grad_fn=<DivBackward0>)
# tensor(6.5548, grad_fn=<DivBackward0>)
# tensor(6.1387, grad_fn=<DivBackward0>)
# tensor(6.7424, grad_fn=<DivBackward0>)
# tensor(5.9990, grad_fn=<DivBackward0>)
# tensor(5.9780, grad_fn=<DivBackward0>)
# tensor(6.0031, grad_fn=<DivBackward0>)
# tensor(6.4572, grad_fn=<DivBackward0>)
# tensor(6.2476, grad_fn=<DivBackward0>)
# tensor(6.5991, grad_fn=<DivBackward0>)
# tensor(6.1334, grad_fn=<DivBackward0>)
# tensor(6.4732, grad_fn=<DivBackward0>)
# tensor(6.2298, grad_fn=<DivBackward0>)
# tensor(6.1852, grad_fn=<DivBackward0>)
# tensor(6.7539, grad_fn=<DivBackward0>)
# tensor(7.1364, grad_fn=<DivBackward0>)
# tensor(5.9170, grad_fn=<DivBackward0>)
# tensor(5.7285, grad_fn=<DivBackward0>)
# tensor(5.7678, grad_fn=<DivBackward0>)
# tensor(5.9382, grad_fn=<DivBackward0>)
# tensor(6.3093, grad_fn=<DivBackward0>)
# tensor(6.0133, grad_fn=<DivBackward0>)
# tensor(6.3883, grad_fn=<DivBackward0>)
# tensor(6.0293, grad_fn=<DivBackward0>)
# tensor(6.2436, grad_fn=<DivBackward0>)
# tensor(6.1750, grad_fn=<DivBackward0>)
# tensor(6.0070, grad_fn=<DivBackward0>)
# tensor(6.0426, grad_fn=<DivBackward0>)
# tensor(5.8067, grad_fn=<DivBackward0>)
# tensor(5.6919, grad_fn=<DivBackward0>)
# tensor(5.7319, grad_fn=<DivBackward0>)
# tensor(5.8876, grad_fn=<DivBackward0>)
# tensor(5.3965, grad_fn=<DivBackward0>)
# tensor(5.7159, grad_fn=<DivBackward0>)
# tensor(5.6975, grad_fn=<DivBackward0>)
# tensor(5.4797, grad_fn=<DivBackward0>)
# tensor(5.6904, grad_fn=<DivBackward0>)
# tensor(5.8622, grad_fn=<DivBackward0>)
# tensor(6.3122, grad_fn=<DivBackward0>)
# tensor(5.2878, grad_fn=<DivBackward0>)
# tensor(5.5133, grad_fn=<DivBackward0>)
# tensor(6.0402, grad_fn=<DivBackward0>)
# tensor(5.7637, grad_fn=<DivBackward0>)
# tensor(5.6881, grad_fn=<DivBackward0>)
# Epoch 5: Training Loss 6.187448135444096
# tensor(5.9823)
# tensor(5.8309)
# tensor(6.3379)
# tensor(5.6006)
# tensor(6.5761)
# tensor(6.2038)
# tensor(6.9349)
# tensor(5.8175)
# tensor(5.5282)
# tensor(6.0038)
# tensor(6.4388)
# tensor(5.0163)
# tensor(6.4667)
# tensor(6.2990)
# tensor(5.8336)
# tensor(5.7930)
# tensor(5.6456)
# tensor(6.3572)
# tensor(6.7252)
# tensor(6.4814)
# tensor(5.3035)
# tensor(6.0492)
# tensor(5.5617)
# tensor(5.5347)
# tensor(5.5053)
# tensor(6.2539)
# tensor(6.1749)
# tensor(5.8599)
# tensor(6.3229)
# tensor(5.7952)
# tensor(6.0259)
# tensor(6.0749)
# tensor(6.4934)
# tensor(6.3724)
# tensor(6.2794)
# tensor(5.8832)
# tensor(6.5804)
# tensor(6.5057)
# tensor(6.0921)
# tensor(6.2398)
# tensor(6.2271)
# tensor(5.9946)
# tensor(6.4102)
# tensor(5.8646)
# tensor(6.2157)
# tensor(5.5739)
# tensor(6.4941)
# tensor(6.2319)
# tensor(5.2990)
# tensor(5.8532)
# tensor(5.9218)
# tensor(6.2243)
# tensor(6.3380)
# tensor(6.7824)
# tensor(5.8410)
# tensor(6.2881)
# Epoch 5: Validation Loss 6.066810599395207
# tensor(5.0819, grad_fn=<DivBackward0>)
# tensor(5.8925, grad_fn=<DivBackward0>)
# tensor(5.3788, grad_fn=<DivBackward0>)
# tensor(5.2795, grad_fn=<DivBackward0>)
# tensor(5.9415, grad_fn=<DivBackward0>)
# tensor(5.5246, grad_fn=<DivBackward0>)
# tensor(5.7138, grad_fn=<DivBackward0>)
# tensor(5.8683, grad_fn=<DivBackward0>)
# tensor(5.9779, grad_fn=<DivBackward0>)
# tensor(5.8127, grad_fn=<DivBackward0>)
# tensor(5.5122, grad_fn=<DivBackward0>)
# tensor(5.4232, grad_fn=<DivBackward0>)
# tensor(5.5635, grad_fn=<DivBackward0>)
# tensor(5.3628, grad_fn=<DivBackward0>)
# tensor(5.5849, grad_fn=<DivBackward0>)
# tensor(5.5439, grad_fn=<DivBackward0>)
# tensor(5.4019, grad_fn=<DivBackward0>)
# tensor(5.2608, grad_fn=<DivBackward0>)
# tensor(5.7936, grad_fn=<DivBackward0>)
# tensor(5.1153, grad_fn=<DivBackward0>)
# tensor(4.9501, grad_fn=<DivBackward0>)
# tensor(5.4082, grad_fn=<DivBackward0>)
# tensor(5.2263, grad_fn=<DivBackward0>)
# tensor(5.5590, grad_fn=<DivBackward0>)
# tensor(5.4630, grad_fn=<DivBackward0>)
# tensor(5.6429, grad_fn=<DivBackward0>)
# tensor(5.2852, grad_fn=<DivBackward0>)
# tensor(5.5110, grad_fn=<DivBackward0>)
# tensor(5.4570, grad_fn=<DivBackward0>)
# tensor(5.5416, grad_fn=<DivBackward0>)
# tensor(4.7265, grad_fn=<DivBackward0>)
# tensor(5.3993, grad_fn=<DivBackward0>)
# tensor(5.0836, grad_fn=<DivBackward0>)
# tensor(5.2091, grad_fn=<DivBackward0>)
# tensor(4.7651, grad_fn=<DivBackward0>)
# tensor(5.4927, grad_fn=<DivBackward0>)
# tensor(5.2982, grad_fn=<DivBackward0>)
# tensor(5.0052, grad_fn=<DivBackward0>)
# tensor(5.1910, grad_fn=<DivBackward0>)
# tensor(5.6458, grad_fn=<DivBackward0>)
# tensor(4.7951, grad_fn=<DivBackward0>)
# tensor(5.0836, grad_fn=<DivBackward0>)
# tensor(5.3465, grad_fn=<DivBackward0>)
# tensor(5.3080, grad_fn=<DivBackward0>)
# tensor(5.1839, grad_fn=<DivBackward0>)
# tensor(4.9226, grad_fn=<DivBackward0>)
# tensor(5.4804, grad_fn=<DivBackward0>)
# tensor(4.9200, grad_fn=<DivBackward0>)
# tensor(4.9368, grad_fn=<DivBackward0>)
# tensor(5.0190, grad_fn=<DivBackward0>)
# tensor(5.0380, grad_fn=<DivBackward0>)
# tensor(4.9527, grad_fn=<DivBackward0>)
# tensor(5.3257, grad_fn=<DivBackward0>)
# tensor(4.8084, grad_fn=<DivBackward0>)
# tensor(5.2535, grad_fn=<DivBackward0>)
# tensor(4.8133, grad_fn=<DivBackward0>)
# Epoch 6: Training Loss 5.322889932564327
# tensor(5.9759)
# tensor(5.0914)
# tensor(5.6113)
# tensor(5.5538)
# tensor(5.4762)
# tensor(4.6389)
# tensor(5.7659)
# tensor(5.8765)
# tensor(4.9080)
# tensor(5.3743)
# tensor(5.2518)
# tensor(5.3572)
# tensor(4.3925)
# tensor(5.1112)
# tensor(5.5984)
# tensor(4.9023)
# tensor(6.0764)
# tensor(5.4494)
# tensor(5.7325)
# tensor(5.3577)
# tensor(5.2138)
# tensor(5.7570)
# tensor(5.4776)
# tensor(5.2775)
# tensor(4.9300)
# tensor(5.5136)
# tensor(5.1500)
# tensor(5.2199)
# tensor(5.0043)
# tensor(5.4362)
# tensor(5.8667)
# tensor(4.9376)
# tensor(5.5555)
# tensor(6.0123)
# tensor(4.9205)
# tensor(5.3128)
# tensor(5.4393)
# tensor(5.0471)
# tensor(5.1169)
# tensor(5.4150)
# tensor(4.9909)
# tensor(5.0701)
# tensor(5.2382)
# tensor(5.7141)
# tensor(5.1606)
# tensor(4.6871)
# tensor(5.8334)
# tensor(4.8078)
# tensor(5.0621)
# tensor(5.2335)
# tensor(5.1176)
# tensor(5.2597)
# tensor(5.2940)
# tensor(5.7437)
# tensor(5.4451)
# tensor(5.4881)
# Epoch 6: Validation Loss 5.313867688179016
# tensor(4.7058, grad_fn=<DivBackward0>)
# tensor(4.8365, grad_fn=<DivBackward0>)
# tensor(5.0418, grad_fn=<DivBackward0>)
# tensor(4.8485, grad_fn=<DivBackward0>)
# tensor(5.3312, grad_fn=<DivBackward0>)
# tensor(4.8682, grad_fn=<DivBackward0>)
# tensor(4.9995, grad_fn=<DivBackward0>)
# tensor(4.8843, grad_fn=<DivBackward0>)
# tensor(4.4607, grad_fn=<DivBackward0>)
# tensor(4.9792, grad_fn=<DivBackward0>)
# tensor(4.7235, grad_fn=<DivBackward0>)
# tensor(4.4052, grad_fn=<DivBackward0>)
# tensor(4.6679, grad_fn=<DivBackward0>)
# tensor(4.7923, grad_fn=<DivBackward0>)
# tensor(4.7308, grad_fn=<DivBackward0>)
# tensor(4.6778, grad_fn=<DivBackward0>)
# tensor(4.4606, grad_fn=<DivBackward0>)
# tensor(4.6450, grad_fn=<DivBackward0>)
# tensor(4.7419, grad_fn=<DivBackward0>)
# tensor(4.7767, grad_fn=<DivBackward0>)
# tensor(4.9604, grad_fn=<DivBackward0>)
# tensor(4.5225, grad_fn=<DivBackward0>)
# tensor(5.3923, grad_fn=<DivBackward0>)
# tensor(5.1283, grad_fn=<DivBackward0>)
# tensor(4.1534, grad_fn=<DivBackward0>)
# tensor(5.0184, grad_fn=<DivBackward0>)
# tensor(4.9194, grad_fn=<DivBackward0>)
# tensor(4.5183, grad_fn=<DivBackward0>)
# tensor(4.5146, grad_fn=<DivBackward0>)
# tensor(4.4059, grad_fn=<DivBackward0>)
# tensor(4.5026, grad_fn=<DivBackward0>)
# tensor(5.0023, grad_fn=<DivBackward0>)
# tensor(4.6609, grad_fn=<DivBackward0>)
# tensor(5.0341, grad_fn=<DivBackward0>)
# tensor(4.4908, grad_fn=<DivBackward0>)
# tensor(4.8118, grad_fn=<DivBackward0>)
# tensor(4.4982, grad_fn=<DivBackward0>)
# tensor(4.9744, grad_fn=<DivBackward0>)
# tensor(4.9018, grad_fn=<DivBackward0>)
# tensor(4.6860, grad_fn=<DivBackward0>)
# tensor(4.5368, grad_fn=<DivBackward0>)
# tensor(4.1033, grad_fn=<DivBackward0>)
# tensor(4.1209, grad_fn=<DivBackward0>)
# tensor(4.5687, grad_fn=<DivBackward0>)
# tensor(5.0289, grad_fn=<DivBackward0>)
# tensor(4.1879, grad_fn=<DivBackward0>)
# tensor(4.7064, grad_fn=<DivBackward0>)
# tensor(4.5168, grad_fn=<DivBackward0>)
# tensor(4.2065, grad_fn=<DivBackward0>)
# tensor(4.5144, grad_fn=<DivBackward0>)
# tensor(4.6907, grad_fn=<DivBackward0>)
# tensor(4.0964, grad_fn=<DivBackward0>)
# tensor(4.1561, grad_fn=<DivBackward0>)
# tensor(4.6145, grad_fn=<DivBackward0>)
# tensor(4.3102, grad_fn=<DivBackward0>)
# tensor(4.6283, grad_fn=<DivBackward0>)
# Epoch 7: Training Loss 4.672517733914511
# tensor(4.9147)
# tensor(4.2177)
# tensor(4.6303)
# tensor(4.5283)
# tensor(4.7500)
# tensor(4.9430)
# tensor(5.0588)
# tensor(4.7695)
# tensor(4.6581)
# tensor(4.2914)
# tensor(4.4616)
# tensor(4.7724)
# tensor(4.2562)
# tensor(4.0971)
# tensor(4.8989)
# tensor(4.9835)
# tensor(4.4055)
# tensor(4.8241)
# tensor(4.5436)
# tensor(4.2161)
# tensor(5.0832)
# tensor(4.8780)
# tensor(4.5796)
# tensor(5.1736)
# tensor(4.3487)
# tensor(4.8289)
# tensor(5.5225)
# tensor(4.7561)
# tensor(5.1615)
# tensor(4.9233)
# tensor(4.8866)
# tensor(4.9242)
# tensor(3.9447)
# tensor(4.7215)
# tensor(4.6203)
# tensor(4.7750)
# tensor(5.0126)
# tensor(4.3735)
# tensor(4.7755)
# tensor(5.5815)
# tensor(4.7430)
# tensor(4.6601)
# tensor(5.0570)
# tensor(4.9221)
# tensor(4.6580)
# tensor(5.3273)
# tensor(5.3359)
# tensor(5.3401)
# tensor(4.7056)
# tensor(4.6072)
# tensor(4.6572)
# tensor(4.4265)
# tensor(4.5458)
# tensor(4.2255)
# tensor(4.5906)
# tensor(4.6744)
# Epoch 7: Validation Loss 4.741458288260868
# tensor(4.4983, grad_fn=<DivBackward0>)
# tensor(4.3014, grad_fn=<DivBackward0>)
# tensor(4.2550, grad_fn=<DivBackward0>)
# tensor(4.4488, grad_fn=<DivBackward0>)
# tensor(3.9422, grad_fn=<DivBackward0>)
# tensor(4.8576, grad_fn=<DivBackward0>)
# tensor(4.3718, grad_fn=<DivBackward0>)
# tensor(4.0511, grad_fn=<DivBackward0>)
# tensor(4.2254, grad_fn=<DivBackward0>)
# tensor(4.5243, grad_fn=<DivBackward0>)
# tensor(4.2496, grad_fn=<DivBackward0>)
# tensor(4.3388, grad_fn=<DivBackward0>)
# tensor(4.5532, grad_fn=<DivBackward0>)
# tensor(4.1566, grad_fn=<DivBackward0>)
# tensor(4.4751, grad_fn=<DivBackward0>)
# tensor(4.3119, grad_fn=<DivBackward0>)
# tensor(4.4044, grad_fn=<DivBackward0>)
# tensor(3.9178, grad_fn=<DivBackward0>)
# tensor(4.4227, grad_fn=<DivBackward0>)
# tensor(4.2080, grad_fn=<DivBackward0>)
# tensor(4.2929, grad_fn=<DivBackward0>)
# tensor(4.0073, grad_fn=<DivBackward0>)
# tensor(4.3239, grad_fn=<DivBackward0>)
# tensor(3.7064, grad_fn=<DivBackward0>)
# tensor(4.5245, grad_fn=<DivBackward0>)
# tensor(4.3408, grad_fn=<DivBackward0>)
# tensor(3.8819, grad_fn=<DivBackward0>)
# tensor(4.1843, grad_fn=<DivBackward0>)
# tensor(3.9733, grad_fn=<DivBackward0>)
# tensor(3.8150, grad_fn=<DivBackward0>)
# tensor(4.3782, grad_fn=<DivBackward0>)
# tensor(4.3055, grad_fn=<DivBackward0>)
# tensor(4.0297, grad_fn=<DivBackward0>)
# tensor(4.5524, grad_fn=<DivBackward0>)
# tensor(3.7660, grad_fn=<DivBackward0>)
# tensor(4.3583, grad_fn=<DivBackward0>)
# tensor(3.7676, grad_fn=<DivBackward0>)
# tensor(3.7729, grad_fn=<DivBackward0>)
# tensor(3.9173, grad_fn=<DivBackward0>)
# tensor(4.4694, grad_fn=<DivBackward0>)
# tensor(3.9573, grad_fn=<DivBackward0>)
# tensor(3.9159, grad_fn=<DivBackward0>)
# tensor(3.8719, grad_fn=<DivBackward0>)
# tensor(3.8009, grad_fn=<DivBackward0>)
# tensor(4.0159, grad_fn=<DivBackward0>)
# tensor(4.2373, grad_fn=<DivBackward0>)
# tensor(3.8219, grad_fn=<DivBackward0>)
# tensor(3.9930, grad_fn=<DivBackward0>)
# tensor(4.1146, grad_fn=<DivBackward0>)
# tensor(4.1518, grad_fn=<DivBackward0>)
# tensor(3.8213, grad_fn=<DivBackward0>)
# tensor(3.8694, grad_fn=<DivBackward0>)
# tensor(4.1296, grad_fn=<DivBackward0>)
# tensor(4.2376, grad_fn=<DivBackward0>)
# tensor(3.9418, grad_fn=<DivBackward0>)
# tensor(3.8502, grad_fn=<DivBackward0>)
# Epoch 8: Training Loss 4.153794484479087
# tensor(4.4862)
# tensor(4.3599)
# tensor(4.2981)
# tensor(3.6385)
# tensor(4.3920)
# tensor(4.1627)
# tensor(4.0886)
# tensor(4.3048)
# tensor(3.8068)
# tensor(3.8985)
# tensor(4.3460)
# tensor(4.4010)
# tensor(3.8962)
# tensor(4.2917)
# tensor(4.0230)
# tensor(3.6268)
# tensor(3.9791)
# tensor(4.5539)
# tensor(4.1102)
# tensor(4.1031)
# tensor(4.2866)
# tensor(3.8079)
# tensor(4.1525)
# tensor(4.2215)
# tensor(4.9794)
# tensor(4.4090)
# tensor(4.1884)
# tensor(4.1718)
# tensor(4.5272)
# tensor(4.1809)
# tensor(4.4848)
# tensor(3.8713)
# tensor(5.0323)
# tensor(4.4212)
# tensor(3.8135)
# tensor(4.2071)
# tensor(4.4722)
# tensor(4.4791)
# tensor(3.9335)
# tensor(4.4604)
# tensor(4.6669)
# tensor(4.7710)
# tensor(5.0507)
# tensor(3.6202)
# tensor(4.5405)
# tensor(3.9457)
# tensor(4.5590)
# tensor(4.4058)
# tensor(4.3867)
# tensor(4.6373)
# tensor(4.8276)
# tensor(4.2277)
# tensor(4.2971)
# tensor(4.4576)
# tensor(4.0996)
# tensor(4.2686)
# Epoch 8: Validation Loss 4.2716261105878015
# tensor(3.7983, grad_fn=<DivBackward0>)
# tensor(3.5255, grad_fn=<DivBackward0>)
# tensor(3.8072, grad_fn=<DivBackward0>)
# tensor(3.7764, grad_fn=<DivBackward0>)
# tensor(3.8421, grad_fn=<DivBackward0>)
# tensor(3.6625, grad_fn=<DivBackward0>)
# tensor(3.5676, grad_fn=<DivBackward0>)
# tensor(3.8912, grad_fn=<DivBackward0>)
# tensor(4.0273, grad_fn=<DivBackward0>)
# tensor(3.4846, grad_fn=<DivBackward0>)
# tensor(3.7007, grad_fn=<DivBackward0>)
# tensor(3.7940, grad_fn=<DivBackward0>)
# tensor(3.7877, grad_fn=<DivBackward0>)
# tensor(4.2085, grad_fn=<DivBackward0>)
# tensor(4.1504, grad_fn=<DivBackward0>)
# tensor(3.8757, grad_fn=<DivBackward0>)
# tensor(4.0898, grad_fn=<DivBackward0>)
# tensor(3.8196, grad_fn=<DivBackward0>)
# tensor(3.7970, grad_fn=<DivBackward0>)
# tensor(3.7901, grad_fn=<DivBackward0>)
# tensor(3.9135, grad_fn=<DivBackward0>)
# tensor(3.8001, grad_fn=<DivBackward0>)
# tensor(3.6724, grad_fn=<DivBackward0>)
# tensor(3.8158, grad_fn=<DivBackward0>)
# tensor(3.5508, grad_fn=<DivBackward0>)
# tensor(3.8066, grad_fn=<DivBackward0>)
# tensor(4.2929, grad_fn=<DivBackward0>)
# tensor(3.8271, grad_fn=<DivBackward0>)
# tensor(3.5159, grad_fn=<DivBackward0>)
# tensor(3.7382, grad_fn=<DivBackward0>)
# tensor(3.7127, grad_fn=<DivBackward0>)
# tensor(3.6638, grad_fn=<DivBackward0>)
# tensor(3.6529, grad_fn=<DivBackward0>)
# tensor(3.9655, grad_fn=<DivBackward0>)
# tensor(3.9003, grad_fn=<DivBackward0>)
# tensor(3.8414, grad_fn=<DivBackward0>)
# tensor(3.3153, grad_fn=<DivBackward0>)
# tensor(3.8001, grad_fn=<DivBackward0>)
# tensor(4.0371, grad_fn=<DivBackward0>)
# tensor(3.2698, grad_fn=<DivBackward0>)
# tensor(3.8009, grad_fn=<DivBackward0>)
# tensor(3.3200, grad_fn=<DivBackward0>)
# tensor(3.6629, grad_fn=<DivBackward0>)
# tensor(3.6249, grad_fn=<DivBackward0>)
# tensor(3.6499, grad_fn=<DivBackward0>)
# tensor(3.5233, grad_fn=<DivBackward0>)
# tensor(3.4581, grad_fn=<DivBackward0>)
# tensor(4.0475, grad_fn=<DivBackward0>)
# tensor(3.2810, grad_fn=<DivBackward0>)
# tensor(3.8190, grad_fn=<DivBackward0>)
# tensor(3.8205, grad_fn=<DivBackward0>)
# tensor(3.7260, grad_fn=<DivBackward0>)
# tensor(3.5381, grad_fn=<DivBackward0>)
# tensor(3.8170, grad_fn=<DivBackward0>)
# tensor(3.3522, grad_fn=<DivBackward0>)
# tensor(3.4357, grad_fn=<DivBackward0>)
# Epoch 9: Training Loss 3.738666300262724
# tensor(2.9984)
# tensor(3.9628)
# tensor(3.6252)
# tensor(4.1152)
# tensor(4.1778)
# tensor(4.0276)
# tensor(4.5695)
# tensor(3.9760)
# tensor(3.6806)
# tensor(3.6214)
# tensor(4.2002)
# tensor(3.7979)
# tensor(3.7651)
# tensor(3.5796)
# tensor(3.9061)
# tensor(3.6088)
# tensor(3.5538)
# tensor(3.8602)
# tensor(3.9275)
# tensor(3.1338)
# tensor(4.0386)
# tensor(3.5317)
# tensor(4.1469)
# tensor(4.2675)
# tensor(3.8189)
# tensor(3.9041)
# tensor(3.9616)
# tensor(3.6840)
# tensor(3.6532)
# tensor(4.4477)
# tensor(3.6035)
# tensor(4.4568)
# tensor(3.3416)
# tensor(3.5336)
# tensor(4.4812)
# tensor(4.7766)
# tensor(4.2680)
# tensor(3.8672)
# tensor(4.0624)
# tensor(4.0563)
# tensor(3.2943)
# tensor(3.8126)
# tensor(3.3024)
# tensor(3.6927)
# tensor(4.2899)
# tensor(4.3544)
# tensor(4.0239)
# tensor(3.6412)
# tensor(3.8952)
# tensor(3.7208)
# tensor(4.0767)
# tensor(4.4209)
# tensor(3.6216)
# tensor(4.2394)
# tensor(4.1876)
# tensor(4.0130)
# Epoch 9: Validation Loss 3.8928224444389343
# tensor(3.5293, grad_fn=<DivBackward0>)
# tensor(3.1516, grad_fn=<DivBackward0>)
# tensor(3.8075, grad_fn=<DivBackward0>)
# tensor(3.9490, grad_fn=<DivBackward0>)
# tensor(3.6722, grad_fn=<DivBackward0>)
# tensor(3.3591, grad_fn=<DivBackward0>)
# tensor(3.5769, grad_fn=<DivBackward0>)
# tensor(3.7855, grad_fn=<DivBackward0>)
# tensor(3.2913, grad_fn=<DivBackward0>)
# tensor(3.2852, grad_fn=<DivBackward0>)
# tensor(3.8011, grad_fn=<DivBackward0>)
# tensor(3.5696, grad_fn=<DivBackward0>)
# tensor(3.4207, grad_fn=<DivBackward0>)
# tensor(3.3499, grad_fn=<DivBackward0>)
# tensor(3.5033, grad_fn=<DivBackward0>)
# tensor(3.6588, grad_fn=<DivBackward0>)
# tensor(3.5911, grad_fn=<DivBackward0>)
# tensor(3.4064, grad_fn=<DivBackward0>)
# tensor(3.5408, grad_fn=<DivBackward0>)
# tensor(3.7606, grad_fn=<DivBackward0>)
# tensor(3.3788, grad_fn=<DivBackward0>)
# tensor(3.6728, grad_fn=<DivBackward0>)
# tensor(3.2152, grad_fn=<DivBackward0>)
# tensor(3.0877, grad_fn=<DivBackward0>)
# tensor(3.6344, grad_fn=<DivBackward0>)
# tensor(3.1615, grad_fn=<DivBackward0>)
# tensor(3.5895, grad_fn=<DivBackward0>)
# tensor(3.3612, grad_fn=<DivBackward0>)
# tensor(2.9056, grad_fn=<DivBackward0>)
# tensor(3.0707, grad_fn=<DivBackward0>)
# tensor(3.0670, grad_fn=<DivBackward0>)
# tensor(3.5097, grad_fn=<DivBackward0>)
# tensor(3.8447, grad_fn=<DivBackward0>)
# tensor(3.3757, grad_fn=<DivBackward0>)
# tensor(3.7044, grad_fn=<DivBackward0>)
# tensor(3.0496, grad_fn=<DivBackward0>)
# tensor(3.6752, grad_fn=<DivBackward0>)
# tensor(2.9479, grad_fn=<DivBackward0>)
# tensor(3.3757, grad_fn=<DivBackward0>)
# tensor(3.3139, grad_fn=<DivBackward0>)
# tensor(3.5885, grad_fn=<DivBackward0>)
# tensor(3.3788, grad_fn=<DivBackward0>)
# tensor(3.1872, grad_fn=<DivBackward0>)
# tensor(3.4158, grad_fn=<DivBackward0>)
# tensor(3.3203, grad_fn=<DivBackward0>)
# tensor(3.6005, grad_fn=<DivBackward0>)
# tensor(3.2250, grad_fn=<DivBackward0>)
# tensor(3.5709, grad_fn=<DivBackward0>)
# tensor(3.3170, grad_fn=<DivBackward0>)
# tensor(3.2557, grad_fn=<DivBackward0>)
# tensor(3.1811, grad_fn=<DivBackward0>)
# tensor(3.0503, grad_fn=<DivBackward0>)
# tensor(3.1738, grad_fn=<DivBackward0>)
# tensor(3.1352, grad_fn=<DivBackward0>)
# tensor(3.2628, grad_fn=<DivBackward0>)
# tensor(3.0621, grad_fn=<DivBackward0>)
# Epoch 10: Training Loss 3.4049317070416043
# tensor(3.0056)
# tensor(3.4654)
# tensor(3.1625)
# tensor(3.8031)
# tensor(3.1418)
# tensor(3.0154)
# tensor(3.4480)
# tensor(3.5645)
# tensor(3.1515)
# tensor(3.7899)
# tensor(3.3237)
# tensor(3.3937)
# tensor(3.5112)
# tensor(3.7483)
# tensor(3.8006)
# tensor(3.9699)
# tensor(3.3112)
# tensor(3.7987)
# tensor(3.8640)
# tensor(3.3091)
# tensor(3.1312)
# tensor(3.6546)
# tensor(4.0402)
# tensor(4.0185)
# tensor(3.6326)
# tensor(3.2995)
# tensor(4.1767)
# tensor(3.8614)
# tensor(3.9114)
# tensor(3.7523)
# tensor(3.4362)
# tensor(3.7205)
# tensor(3.0728)
# tensor(2.8310)
# tensor(3.7666)
# tensor(3.1037)
# tensor(3.6328)
# tensor(3.9344)
# tensor(4.0941)
# tensor(3.6297)
# tensor(3.6668)
# tensor(3.4788)
# tensor(4.1158)
# tensor(3.6920)
# tensor(3.5060)
# tensor(4.3521)
# tensor(3.5987)
# tensor(4.5206)
# tensor(3.3385)
# tensor(3.8082)
# tensor(3.3609)
# tensor(3.8365)
# tensor(3.3912)
# tensor(3.1536)
# tensor(3.4258)
# tensor(3.5768)
# Epoch 10: Validation Loss 3.5818981187684193
# tensor(3.3385, grad_fn=<DivBackward0>)
# tensor(3.0832, grad_fn=<DivBackward0>)
# tensor(3.3994, grad_fn=<DivBackward0>)
# tensor(3.0459, grad_fn=<DivBackward0>)
# tensor(3.2530, grad_fn=<DivBackward0>)
# tensor(3.0322, grad_fn=<DivBackward0>)
# tensor(3.1583, grad_fn=<DivBackward0>)
# tensor(3.6308, grad_fn=<DivBackward0>)
# tensor(3.0866, grad_fn=<DivBackward0>)
# tensor(3.2746, grad_fn=<DivBackward0>)
# tensor(2.8462, grad_fn=<DivBackward0>)
# tensor(3.3232, grad_fn=<DivBackward0>)
# tensor(3.0006, grad_fn=<DivBackward0>)
# tensor(2.9938, grad_fn=<DivBackward0>)
# tensor(3.1994, grad_fn=<DivBackward0>)
# tensor(3.2803, grad_fn=<DivBackward0>)
# tensor(2.8785, grad_fn=<DivBackward0>)
# tensor(3.2764, grad_fn=<DivBackward0>)
# tensor(3.1972, grad_fn=<DivBackward0>)
# tensor(3.2778, grad_fn=<DivBackward0>)
# tensor(3.4320, grad_fn=<DivBackward0>)
# tensor(2.8357, grad_fn=<DivBackward0>)
# tensor(3.3095, grad_fn=<DivBackward0>)
# tensor(2.9342, grad_fn=<DivBackward0>)
# tensor(2.8580, grad_fn=<DivBackward0>)
# tensor(3.3076, grad_fn=<DivBackward0>)
# tensor(3.0590, grad_fn=<DivBackward0>)
# tensor(2.9426, grad_fn=<DivBackward0>)
# tensor(3.0798, grad_fn=<DivBackward0>)
# tensor(3.2472, grad_fn=<DivBackward0>)
# tensor(3.0602, grad_fn=<DivBackward0>)
# tensor(3.0172, grad_fn=<DivBackward0>)
# tensor(3.2804, grad_fn=<DivBackward0>)
# tensor(3.0426, grad_fn=<DivBackward0>)
# tensor(3.3456, grad_fn=<DivBackward0>)
# tensor(3.2758, grad_fn=<DivBackward0>)
# tensor(2.9277, grad_fn=<DivBackward0>)
# tensor(2.9355, grad_fn=<DivBackward0>)
# tensor(2.9483, grad_fn=<DivBackward0>)
# tensor(2.9090, grad_fn=<DivBackward0>)
# tensor(3.3990, grad_fn=<DivBackward0>)
# tensor(2.9690, grad_fn=<DivBackward0>)
# tensor(2.8530, grad_fn=<DivBackward0>)
# tensor(3.3232, grad_fn=<DivBackward0>)
# tensor(3.4304, grad_fn=<DivBackward0>)
# tensor(3.0115, grad_fn=<DivBackward0>)
# tensor(2.8461, grad_fn=<DivBackward0>)
# tensor(3.2251, grad_fn=<DivBackward0>)
# tensor(2.7121, grad_fn=<DivBackward0>)
# tensor(3.0776, grad_fn=<DivBackward0>)
# tensor(3.3654, grad_fn=<DivBackward0>)
# tensor(3.1770, grad_fn=<DivBackward0>)
# tensor(2.8997, grad_fn=<DivBackward0>)
# tensor(3.0834, grad_fn=<DivBackward0>)
# tensor(3.1816, grad_fn=<DivBackward0>)
# tensor(2.8277, grad_fn=<DivBackward0>)
# Epoch 11: Training Loss 3.1197490777288164
# tensor(3.2049)
# tensor(3.3955)
# tensor(3.4200)
# tensor(3.6074)
# tensor(3.7697)
# tensor(3.4998)
# tensor(3.7991)
# tensor(3.8045)
# tensor(3.2477)
# tensor(3.8585)
# tensor(2.9319)
# tensor(3.0362)
# tensor(3.7067)
# tensor(3.2565)
# tensor(3.4250)
# tensor(3.1876)
# tensor(2.8869)
# tensor(3.2403)
# tensor(3.6000)
# tensor(2.7275)
# tensor(3.8165)
# tensor(3.1330)
# tensor(3.4356)
# tensor(3.0539)
# tensor(3.5094)
# tensor(3.4570)
# tensor(3.0181)
# tensor(3.2585)
# tensor(3.0726)
# tensor(3.3133)
# tensor(3.0105)
# tensor(3.7172)
# tensor(2.7464)
# tensor(3.2582)
# tensor(3.8319)
# tensor(2.6953)
# tensor(3.1875)
# tensor(3.3864)
# tensor(3.6940)
# tensor(3.3016)
# tensor(3.1445)
# tensor(3.1397)
# tensor(3.4765)
# tensor(3.1402)
# tensor(3.4384)
# tensor(3.5209)
# tensor(3.1401)
# tensor(3.1637)
# tensor(3.3485)
# tensor(3.2708)
# tensor(3.4028)
# tensor(3.6944)
# tensor(3.4122)
# tensor(3.4307)
# tensor(3.5824)
# tensor(2.5944)
# Epoch 11: Validation Loss 3.3327853168760027
# tensor(2.9563, grad_fn=<DivBackward0>)
# tensor(2.6374, grad_fn=<DivBackward0>)
# tensor(3.1019, grad_fn=<DivBackward0>)
# tensor(3.0792, grad_fn=<DivBackward0>)
# tensor(2.8411, grad_fn=<DivBackward0>)
# tensor(2.7604, grad_fn=<DivBackward0>)
# tensor(2.9072, grad_fn=<DivBackward0>)
# tensor(2.8753, grad_fn=<DivBackward0>)
# tensor(3.0400, grad_fn=<DivBackward0>)
# tensor(3.1961, grad_fn=<DivBackward0>)
# tensor(3.0042, grad_fn=<DivBackward0>)
# tensor(2.5036, grad_fn=<DivBackward0>)
# tensor(3.0044, grad_fn=<DivBackward0>)
# tensor(2.7262, grad_fn=<DivBackward0>)
# tensor(2.9968, grad_fn=<DivBackward0>)
# tensor(2.9247, grad_fn=<DivBackward0>)
# tensor(2.9966, grad_fn=<DivBackward0>)
# tensor(2.5923, grad_fn=<DivBackward0>)
# tensor(2.8049, grad_fn=<DivBackward0>)
# tensor(3.0821, grad_fn=<DivBackward0>)
# tensor(2.7145, grad_fn=<DivBackward0>)
# tensor(2.8300, grad_fn=<DivBackward0>)
# tensor(3.0856, grad_fn=<DivBackward0>)
# tensor(3.0230, grad_fn=<DivBackward0>)
# tensor(2.8260, grad_fn=<DivBackward0>)
# tensor(2.9893, grad_fn=<DivBackward0>)
# tensor(2.6783, grad_fn=<DivBackward0>)
# tensor(3.2534, grad_fn=<DivBackward0>)
# tensor(2.9377, grad_fn=<DivBackward0>)
# tensor(2.7756, grad_fn=<DivBackward0>)
# tensor(3.2765, grad_fn=<DivBackward0>)
# tensor(2.9669, grad_fn=<DivBackward0>)
# tensor(2.7989, grad_fn=<DivBackward0>)
# tensor(2.8222, grad_fn=<DivBackward0>)
# tensor(3.0418, grad_fn=<DivBackward0>)
# tensor(2.8642, grad_fn=<DivBackward0>)
# tensor(2.9111, grad_fn=<DivBackward0>)
# tensor(2.8239, grad_fn=<DivBackward0>)
# tensor(2.6068, grad_fn=<DivBackward0>)
# tensor(2.9486, grad_fn=<DivBackward0>)
# tensor(3.2460, grad_fn=<DivBackward0>)
# tensor(2.7993, grad_fn=<DivBackward0>)
# tensor(2.9730, grad_fn=<DivBackward0>)
# tensor(2.7317, grad_fn=<DivBackward0>)
# tensor(2.8303, grad_fn=<DivBackward0>)
# tensor(2.7899, grad_fn=<DivBackward0>)
# tensor(2.8485, grad_fn=<DivBackward0>)
# tensor(2.5922, grad_fn=<DivBackward0>)
# tensor(3.3218, grad_fn=<DivBackward0>)
# tensor(2.8538, grad_fn=<DivBackward0>)
# tensor(2.5456, grad_fn=<DivBackward0>)
# tensor(2.5666, grad_fn=<DivBackward0>)
# tensor(2.8074, grad_fn=<DivBackward0>)
# tensor(2.5955, grad_fn=<DivBackward0>)
# tensor(2.7498, grad_fn=<DivBackward0>)
# tensor(2.8825, grad_fn=<DivBackward0>)
# Epoch 12: Training Loss 2.8810527324676514
# tensor(3.2022)
# tensor(2.9855)
# tensor(3.2197)
# tensor(3.3798)
# tensor(3.0434)
# tensor(2.9671)
# tensor(2.7612)
# tensor(2.8104)
# tensor(3.3720)
# tensor(2.4523)
# tensor(3.5073)
# tensor(3.4978)
# tensor(3.4609)
# tensor(2.7893)
# tensor(4.1756)
# tensor(2.7108)
# tensor(2.5207)
# tensor(2.8481)
# tensor(3.1615)
# tensor(3.0829)
# tensor(2.4766)
# tensor(2.9255)
# tensor(3.0522)
# tensor(3.1365)
# tensor(3.4622)
# tensor(2.3969)
# tensor(3.3259)
# tensor(3.0731)
# tensor(3.1240)
# tensor(3.1948)
# tensor(2.9058)
# tensor(2.9621)
# tensor(2.8049)
# tensor(3.2664)
# tensor(2.9553)
# tensor(2.7126)
# tensor(3.3961)
# tensor(3.6086)
# tensor(2.8288)
# tensor(3.5931)
# tensor(3.0152)
# tensor(2.8287)
# tensor(3.1972)
# tensor(3.0586)
# tensor(3.2983)
# tensor(3.4781)
# tensor(3.6838)
# tensor(3.3869)
# tensor(2.9916)
# tensor(3.1135)
# tensor(2.9482)
# tensor(3.4855)
# tensor(3.0280)
# tensor(2.9544)
# tensor(3.6258)
# tensor(2.7109)
# Epoch 12: Validation Loss 3.1093948696340834
# tensor(2.7457, grad_fn=<DivBackward0>)
# tensor(2.6069, grad_fn=<DivBackward0>)
# tensor(3.0010, grad_fn=<DivBackward0>)
# tensor(2.4917, grad_fn=<DivBackward0>)
# tensor(2.6120, grad_fn=<DivBackward0>)
# tensor(2.6088, grad_fn=<DivBackward0>)
# tensor(2.9087, grad_fn=<DivBackward0>)
# tensor(2.9466, grad_fn=<DivBackward0>)
# tensor(2.7963, grad_fn=<DivBackward0>)
# tensor(2.7518, grad_fn=<DivBackward0>)
# tensor(2.8308, grad_fn=<DivBackward0>)
# tensor(2.5387, grad_fn=<DivBackward0>)
# tensor(2.7406, grad_fn=<DivBackward0>)
# tensor(2.8189, grad_fn=<DivBackward0>)
# tensor(2.8359, grad_fn=<DivBackward0>)
# tensor(2.7442, grad_fn=<DivBackward0>)
# tensor(2.5790, grad_fn=<DivBackward0>)
# tensor(2.9255, grad_fn=<DivBackward0>)
# tensor(2.7147, grad_fn=<DivBackward0>)
# tensor(2.7966, grad_fn=<DivBackward0>)
# tensor(2.6368, grad_fn=<DivBackward0>)
# tensor(2.6525, grad_fn=<DivBackward0>)
# tensor(2.7251, grad_fn=<DivBackward0>)
# tensor(2.6704, grad_fn=<DivBackward0>)
# tensor(2.6074, grad_fn=<DivBackward0>)
# tensor(2.7233, grad_fn=<DivBackward0>)
# tensor(2.6920, grad_fn=<DivBackward0>)
# tensor(2.6830, grad_fn=<DivBackward0>)
# tensor(2.4332, grad_fn=<DivBackward0>)
# tensor(2.5103, grad_fn=<DivBackward0>)
# tensor(2.4634, grad_fn=<DivBackward0>)
# tensor(2.6641, grad_fn=<DivBackward0>)
# tensor(2.7527, grad_fn=<DivBackward0>)
# tensor(2.4460, grad_fn=<DivBackward0>)
# tensor(2.3980, grad_fn=<DivBackward0>)
# tensor(2.6654, grad_fn=<DivBackward0>)
# tensor(2.3883, grad_fn=<DivBackward0>)
# tensor(2.7494, grad_fn=<DivBackward0>)
# tensor(2.4512, grad_fn=<DivBackward0>)
# tensor(2.8610, grad_fn=<DivBackward0>)
# tensor(2.4795, grad_fn=<DivBackward0>)
# tensor(2.6007, grad_fn=<DivBackward0>)
# tensor(2.7431, grad_fn=<DivBackward0>)
# tensor(2.5596, grad_fn=<DivBackward0>)
# tensor(2.7960, grad_fn=<DivBackward0>)
# tensor(2.6587, grad_fn=<DivBackward0>)
# tensor(2.8408, grad_fn=<DivBackward0>)
# tensor(2.4154, grad_fn=<DivBackward0>)
# tensor(2.7873, grad_fn=<DivBackward0>)
# tensor(2.6814, grad_fn=<DivBackward0>)
# tensor(3.0102, grad_fn=<DivBackward0>)
# tensor(2.5677, grad_fn=<DivBackward0>)
# tensor(2.5280, grad_fn=<DivBackward0>)
# tensor(2.7649, grad_fn=<DivBackward0>)
# tensor(2.7178, grad_fn=<DivBackward0>)
# tensor(2.3527, grad_fn=<DivBackward0>)
# Epoch 13: Training Loss 2.6727067615304674
# tensor(2.8395)
# tensor(2.9414)
# tensor(2.9386)
# tensor(2.6481)
# tensor(2.6432)
# tensor(2.7672)
# tensor(2.8665)
# tensor(3.3656)
# tensor(2.9257)
# tensor(3.1398)
# tensor(2.4395)
# tensor(3.0803)
# tensor(3.3362)
# tensor(3.0970)
# tensor(3.3333)
# tensor(2.7676)
# tensor(3.0105)
# tensor(2.8585)
# tensor(2.5688)
# tensor(3.0343)
# tensor(2.9752)
# tensor(3.3061)
# tensor(3.2082)
# tensor(2.8552)
# tensor(2.6920)
# tensor(2.8094)
# tensor(3.2577)
# tensor(2.4421)
# tensor(3.1183)
# tensor(2.4991)
# tensor(2.9789)
# tensor(3.0375)
# tensor(2.4700)
# tensor(2.8617)
# tensor(3.1856)
# tensor(2.7167)
# tensor(2.8901)
# tensor(2.5042)
# tensor(3.2260)
# tensor(2.5078)
# tensor(3.1792)
# tensor(3.2869)
# tensor(3.3020)
# tensor(2.8760)
# tensor(2.8304)
# tensor(3.1680)
# tensor(3.1962)
# tensor(2.7828)
# tensor(2.3935)
# tensor(2.7694)
# tensor(2.5256)
# tensor(2.6978)
# tensor(2.5867)
# tensor(3.3207)
# tensor(2.8278)
# tensor(3.4115)
# Epoch 13: Validation Loss 2.8971355259418488
# tensor(2.6247, grad_fn=<DivBackward0>)
# tensor(2.2482, grad_fn=<DivBackward0>)
# tensor(2.4156, grad_fn=<DivBackward0>)
# tensor(2.6443, grad_fn=<DivBackward0>)
# tensor(2.5753, grad_fn=<DivBackward0>)
# tensor(2.8174, grad_fn=<DivBackward0>)
# tensor(2.6049, grad_fn=<DivBackward0>)
# tensor(2.5115, grad_fn=<DivBackward0>)
# tensor(2.6986, grad_fn=<DivBackward0>)
# tensor(2.7650, grad_fn=<DivBackward0>)
# tensor(2.8460, grad_fn=<DivBackward0>)
# tensor(2.6707, grad_fn=<DivBackward0>)
# tensor(2.5969, grad_fn=<DivBackward0>)
# tensor(2.5143, grad_fn=<DivBackward0>)
# tensor(2.6270, grad_fn=<DivBackward0>)
# tensor(2.2092, grad_fn=<DivBackward0>)
# tensor(2.4186, grad_fn=<DivBackward0>)
# tensor(2.6041, grad_fn=<DivBackward0>)
# tensor(2.4934, grad_fn=<DivBackward0>)
# tensor(2.4131, grad_fn=<DivBackward0>)
# tensor(2.4480, grad_fn=<DivBackward0>)
# tensor(2.3675, grad_fn=<DivBackward0>)
# tensor(2.6050, grad_fn=<DivBackward0>)
# tensor(2.3392, grad_fn=<DivBackward0>)
# tensor(2.4035, grad_fn=<DivBackward0>)
# tensor(2.2828, grad_fn=<DivBackward0>)
# tensor(2.5946, grad_fn=<DivBackward0>)
# tensor(2.6463, grad_fn=<DivBackward0>)
# tensor(2.3590, grad_fn=<DivBackward0>)
# tensor(2.5668, grad_fn=<DivBackward0>)
# tensor(2.5021, grad_fn=<DivBackward0>)
# tensor(2.4210, grad_fn=<DivBackward0>)
# tensor(2.5730, grad_fn=<DivBackward0>)
# tensor(2.2770, grad_fn=<DivBackward0>)
# tensor(2.5617, grad_fn=<DivBackward0>)
# tensor(2.4818, grad_fn=<DivBackward0>)
# tensor(2.6237, grad_fn=<DivBackward0>)
# tensor(2.3406, grad_fn=<DivBackward0>)
# tensor(2.4074, grad_fn=<DivBackward0>)
# tensor(2.8267, grad_fn=<DivBackward0>)
# tensor(2.2431, grad_fn=<DivBackward0>)
# tensor(2.7201, grad_fn=<DivBackward0>)
# tensor(2.2866, grad_fn=<DivBackward0>)
# tensor(2.6183, grad_fn=<DivBackward0>)
# tensor(2.3829, grad_fn=<DivBackward0>)
# tensor(2.1848, grad_fn=<DivBackward0>)
# tensor(2.3485, grad_fn=<DivBackward0>)
# tensor(2.4343, grad_fn=<DivBackward0>)
# tensor(2.7017, grad_fn=<DivBackward0>)
# tensor(2.6215, grad_fn=<DivBackward0>)
# tensor(2.2298, grad_fn=<DivBackward0>)
# tensor(2.5731, grad_fn=<DivBackward0>)
# tensor(2.5529, grad_fn=<DivBackward0>)
# tensor(2.6181, grad_fn=<DivBackward0>)
# tensor(2.2606, grad_fn=<DivBackward0>)
# tensor(2.3504, grad_fn=<DivBackward0>)
# Epoch 14: Training Loss 2.5009506004197255
# tensor(3.4793)
# tensor(2.8413)
# tensor(2.8693)
# tensor(3.4203)
# tensor(2.8294)
# tensor(2.6778)
# tensor(2.4098)
# tensor(2.6987)
# tensor(3.0395)
# tensor(2.6711)
# tensor(2.8086)
# tensor(2.7725)
# tensor(2.6056)
# tensor(2.3373)
# tensor(2.2629)
# tensor(3.0452)
# tensor(3.3914)
# tensor(3.1191)
# tensor(2.3697)
# tensor(2.6478)
# tensor(3.0162)
# tensor(2.7184)
# tensor(2.7284)
# tensor(2.4216)
# tensor(2.4952)
# tensor(2.6604)
# tensor(2.7347)
# tensor(2.5898)
# tensor(3.2462)
# tensor(2.8672)
# tensor(2.4032)
# tensor(2.6070)
# tensor(2.0249)
# tensor(2.3911)
# tensor(2.9772)
# tensor(2.7228)
# tensor(2.2964)
# tensor(2.7286)
# tensor(2.5893)
# tensor(3.0315)
# tensor(2.3722)
# tensor(2.6344)
# tensor(3.1054)
# tensor(2.9020)
# tensor(2.5340)
# tensor(2.7464)
# tensor(2.9015)
# tensor(2.7485)
# tensor(2.8764)
# tensor(2.6175)
# tensor(2.7520)
# tensor(2.1561)
# tensor(2.4461)
# tensor(2.6808)
# tensor(3.2842)
# tensor(3.7142)
# Epoch 14: Validation Loss 2.7259699489389146
# tensor(2.4776, grad_fn=<DivBackward0>)
# tensor(2.5866, grad_fn=<DivBackward0>)
# tensor(2.5287, grad_fn=<DivBackward0>)
# tensor(2.3921, grad_fn=<DivBackward0>)
# tensor(2.2869, grad_fn=<DivBackward0>)
# tensor(2.2771, grad_fn=<DivBackward0>)
# tensor(2.2557, grad_fn=<DivBackward0>)
# tensor(2.3669, grad_fn=<DivBackward0>)
# tensor(2.4629, grad_fn=<DivBackward0>)
# tensor(1.9483, grad_fn=<DivBackward0>)
# tensor(2.0792, grad_fn=<DivBackward0>)
# tensor(2.5487, grad_fn=<DivBackward0>)
# tensor(2.2384, grad_fn=<DivBackward0>)
# tensor(2.5579, grad_fn=<DivBackward0>)
# tensor(2.1434, grad_fn=<DivBackward0>)
# tensor(2.6007, grad_fn=<DivBackward0>)
# tensor(2.4353, grad_fn=<DivBackward0>)
# tensor(2.4297, grad_fn=<DivBackward0>)
# tensor(2.3969, grad_fn=<DivBackward0>)
# tensor(2.5218, grad_fn=<DivBackward0>)
# tensor(2.2520, grad_fn=<DivBackward0>)
# tensor(2.2245, grad_fn=<DivBackward0>)
# tensor(2.4156, grad_fn=<DivBackward0>)
# tensor(2.2537, grad_fn=<DivBackward0>)
# tensor(2.3204, grad_fn=<DivBackward0>)
# tensor(2.3263, grad_fn=<DivBackward0>)
# tensor(2.5792, grad_fn=<DivBackward0>)
# tensor(2.6791, grad_fn=<DivBackward0>)
# tensor(2.3241, grad_fn=<DivBackward0>)
# tensor(2.3132, grad_fn=<DivBackward0>)
# tensor(2.3140, grad_fn=<DivBackward0>)
# tensor(2.3534, grad_fn=<DivBackward0>)
# tensor(2.1375, grad_fn=<DivBackward0>)
# tensor(2.4298, grad_fn=<DivBackward0>)
# tensor(2.5583, grad_fn=<DivBackward0>)
# tensor(2.2698, grad_fn=<DivBackward0>)
# tensor(2.5408, grad_fn=<DivBackward0>)
# tensor(2.1545, grad_fn=<DivBackward0>)
# tensor(2.3620, grad_fn=<DivBackward0>)
# tensor(2.3633, grad_fn=<DivBackward0>)
# tensor(2.3983, grad_fn=<DivBackward0>)
# tensor(2.2858, grad_fn=<DivBackward0>)
# tensor(2.2286, grad_fn=<DivBackward0>)
# tensor(2.0630, grad_fn=<DivBackward0>)
# tensor(2.0332, grad_fn=<DivBackward0>)
# tensor(2.3491, grad_fn=<DivBackward0>)
# tensor(2.2178, grad_fn=<DivBackward0>)
# tensor(2.4782, grad_fn=<DivBackward0>)
# tensor(2.4900, grad_fn=<DivBackward0>)
# tensor(2.2280, grad_fn=<DivBackward0>)
# tensor(2.1558, grad_fn=<DivBackward0>)
# tensor(2.4264, grad_fn=<DivBackward0>)
# tensor(2.1930, grad_fn=<DivBackward0>)
# tensor(2.2507, grad_fn=<DivBackward0>)
# tensor(2.3087, grad_fn=<DivBackward0>)
# tensor(2.6340, grad_fn=<DivBackward0>)
# Epoch 15: Training Loss 2.3472689049584523
# tensor(3.1376)
# tensor(2.4609)
# tensor(2.3788)
# tensor(2.8182)
# tensor(2.6928)
# tensor(2.8943)
# tensor(2.5335)
# tensor(2.6181)
# tensor(2.5365)
# tensor(3.0159)
# tensor(2.2889)
# tensor(3.1542)
# tensor(3.1911)
# tensor(2.5133)
# tensor(2.5723)
# tensor(2.1133)
# tensor(2.8389)
# tensor(2.5714)
# tensor(2.6651)
# tensor(2.7016)
# tensor(2.5959)
# tensor(2.6762)
# tensor(2.8257)
# tensor(2.8665)
# tensor(2.4778)
# tensor(2.2982)
# tensor(2.3021)
# tensor(2.7755)
# tensor(3.2400)
# tensor(2.3162)
# tensor(2.9117)
# tensor(2.4794)
# tensor(3.0124)
# tensor(2.4060)
# tensor(3.0748)
# tensor(2.6744)
# tensor(3.0454)
# tensor(2.0084)
# tensor(1.9876)
# tensor(2.7033)
# tensor(2.4139)
# tensor(2.4817)
# tensor(2.4362)
# tensor(2.2429)
# tensor(3.0323)
# tensor(2.4878)
# tensor(2.6923)
# tensor(2.4982)
# tensor(2.2821)
# tensor(2.3969)
# tensor(2.0690)
# tensor(2.7697)
# tensor(1.9842)
# tensor(2.5784)
# tensor(2.9087)
# tensor(2.1275)
# Epoch 15: Validation Loss 2.612185361129897
# tensor(2.3618, grad_fn=<DivBackward0>)
# tensor(2.4977, grad_fn=<DivBackward0>)
# tensor(2.3487, grad_fn=<DivBackward0>)
# tensor(2.2460, grad_fn=<DivBackward0>)
# tensor(2.3298, grad_fn=<DivBackward0>)
# tensor(2.3846, grad_fn=<DivBackward0>)
# tensor(2.3750, grad_fn=<DivBackward0>)
# tensor(2.0231, grad_fn=<DivBackward0>)
# tensor(2.3185, grad_fn=<DivBackward0>)
# tensor(2.3807, grad_fn=<DivBackward0>)
# tensor(2.2251, grad_fn=<DivBackward0>)
# tensor(1.9092, grad_fn=<DivBackward0>)
# tensor(2.4803, grad_fn=<DivBackward0>)
# tensor(2.1432, grad_fn=<DivBackward0>)
# tensor(2.1820, grad_fn=<DivBackward0>)
# tensor(2.2365, grad_fn=<DivBackward0>)
# tensor(2.2732, grad_fn=<DivBackward0>)
# tensor(2.1063, grad_fn=<DivBackward0>)
# tensor(2.2041, grad_fn=<DivBackward0>)
# tensor(2.3059, grad_fn=<DivBackward0>)
# tensor(2.2216, grad_fn=<DivBackward0>)
# tensor(2.1637, grad_fn=<DivBackward0>)
# tensor(2.0082, grad_fn=<DivBackward0>)
# tensor(2.2538, grad_fn=<DivBackward0>)
# tensor(2.2151, grad_fn=<DivBackward0>)
# tensor(2.0134, grad_fn=<DivBackward0>)
# tensor(2.1775, grad_fn=<DivBackward0>)
# tensor(2.1036, grad_fn=<DivBackward0>)
# tensor(2.2210, grad_fn=<DivBackward0>)
# tensor(2.3345, grad_fn=<DivBackward0>)
# tensor(2.1486, grad_fn=<DivBackward0>)
# tensor(1.9661, grad_fn=<DivBackward0>)
# tensor(2.2122, grad_fn=<DivBackward0>)
# tensor(2.4841, grad_fn=<DivBackward0>)
# tensor(2.3131, grad_fn=<DivBackward0>)
# tensor(2.1086, grad_fn=<DivBackward0>)
# tensor(2.4786, grad_fn=<DivBackward0>)
# tensor(2.0955, grad_fn=<DivBackward0>)
# tensor(2.2550, grad_fn=<DivBackward0>)
# tensor(2.6006, grad_fn=<DivBackward0>)
# tensor(2.1142, grad_fn=<DivBackward0>)
# tensor(2.0853, grad_fn=<DivBackward0>)
# tensor(2.2910, grad_fn=<DivBackward0>)
# tensor(2.1381, grad_fn=<DivBackward0>)
# tensor(2.1965, grad_fn=<DivBackward0>)
# tensor(2.0731, grad_fn=<DivBackward0>)
# tensor(1.9514, grad_fn=<DivBackward0>)
# tensor(2.1940, grad_fn=<DivBackward0>)
# tensor(1.9545, grad_fn=<DivBackward0>)
# tensor(2.0494, grad_fn=<DivBackward0>)
# tensor(2.0791, grad_fn=<DivBackward0>)
# tensor(2.2720, grad_fn=<DivBackward0>)
# tensor(2.1938, grad_fn=<DivBackward0>)
# tensor(2.1870, grad_fn=<DivBackward0>)
# tensor(2.2093, grad_fn=<DivBackward0>)
# tensor(2.1918, grad_fn=<DivBackward0>)
# Epoch 16: Training Loss 2.2122594160693034
# tensor(2.1943)
# tensor(2.5953)
# tensor(2.3827)
# tensor(2.7295)
# tensor(2.3475)
# tensor(2.4992)
# tensor(1.9478)
# tensor(2.1853)
# tensor(2.0168)
# tensor(2.6031)
# tensor(2.5013)
# tensor(2.2922)
# tensor(2.6310)
# tensor(2.0891)
# tensor(2.4852)
# tensor(2.7422)
# tensor(2.3447)
# tensor(2.7430)
# tensor(2.3878)
# tensor(2.3602)
# tensor(2.6548)
# tensor(2.3225)
# tensor(2.4095)
# tensor(2.3690)
# tensor(2.7778)
# tensor(2.4499)
# tensor(2.1041)
# tensor(3.1836)
# tensor(2.6652)
# tensor(2.3771)
# tensor(2.8818)
# tensor(2.1335)
# tensor(2.1431)
# tensor(2.4345)
# tensor(3.0421)
# tensor(2.3546)
# tensor(2.4703)
# tensor(2.5442)
# tensor(2.3769)
# tensor(2.2384)
# tensor(2.5006)
# tensor(2.4507)
# tensor(3.1221)
# tensor(2.6556)
# tensor(2.5580)
# tensor(2.5967)
# tensor(2.4593)
# tensor(2.5718)
# tensor(2.7178)
# tensor(2.2885)
# tensor(1.9406)
# tensor(2.1424)
# tensor(2.5757)
# tensor(2.3852)
# tensor(3.1133)
# tensor(2.5350)
# Epoch 16: Validation Loss 2.469305781381471
# tensor(1.9022, grad_fn=<DivBackward0>)
# tensor(1.9693, grad_fn=<DivBackward0>)
# tensor(2.4054, grad_fn=<DivBackward0>)
# tensor(2.1806, grad_fn=<DivBackward0>)
# tensor(2.3260, grad_fn=<DivBackward0>)
# tensor(1.9433, grad_fn=<DivBackward0>)
# tensor(2.2625, grad_fn=<DivBackward0>)
# tensor(2.1922, grad_fn=<DivBackward0>)
# tensor(2.2115, grad_fn=<DivBackward0>)
# tensor(2.1677, grad_fn=<DivBackward0>)
# tensor(2.2090, grad_fn=<DivBackward0>)
# tensor(2.1373, grad_fn=<DivBackward0>)
# tensor(2.1735, grad_fn=<DivBackward0>)
# tensor(2.1041, grad_fn=<DivBackward0>)
# tensor(2.3633, grad_fn=<DivBackward0>)
# tensor(2.2515, grad_fn=<DivBackward0>)
# tensor(1.8115, grad_fn=<DivBackward0>)
# tensor(2.0331, grad_fn=<DivBackward0>)
# tensor(2.0084, grad_fn=<DivBackward0>)
# tensor(2.1092, grad_fn=<DivBackward0>)
# tensor(2.0503, grad_fn=<DivBackward0>)
# tensor(2.2883, grad_fn=<DivBackward0>)
# tensor(2.1746, grad_fn=<DivBackward0>)
# tensor(2.0852, grad_fn=<DivBackward0>)
# tensor(2.2541, grad_fn=<DivBackward0>)
# tensor(2.1317, grad_fn=<DivBackward0>)
# tensor(2.1044, grad_fn=<DivBackward0>)
# tensor(2.1055, grad_fn=<DivBackward0>)
# tensor(2.0405, grad_fn=<DivBackward0>)
# tensor(2.1397, grad_fn=<DivBackward0>)
# tensor(1.9315, grad_fn=<DivBackward0>)
# tensor(1.9600, grad_fn=<DivBackward0>)
# tensor(2.1687, grad_fn=<DivBackward0>)
# tensor(2.2189, grad_fn=<DivBackward0>)
# tensor(2.0958, grad_fn=<DivBackward0>)
# tensor(2.1398, grad_fn=<DivBackward0>)
# tensor(2.1555, grad_fn=<DivBackward0>)
# tensor(2.0508, grad_fn=<DivBackward0>)
# tensor(1.9665, grad_fn=<DivBackward0>)
# tensor(2.3959, grad_fn=<DivBackward0>)
# tensor(1.8783, grad_fn=<DivBackward0>)
# tensor(2.0866, grad_fn=<DivBackward0>)
# tensor(1.9507, grad_fn=<DivBackward0>)
# tensor(2.2231, grad_fn=<DivBackward0>)
# tensor(1.9756, grad_fn=<DivBackward0>)
# tensor(1.8354, grad_fn=<DivBackward0>)
# tensor(2.0601, grad_fn=<DivBackward0>)
# tensor(2.0614, grad_fn=<DivBackward0>)
# tensor(1.7004, grad_fn=<DivBackward0>)
# tensor(2.1746, grad_fn=<DivBackward0>)
# tensor(1.8921, grad_fn=<DivBackward0>)
# tensor(2.1419, grad_fn=<DivBackward0>)
# tensor(2.2305, grad_fn=<DivBackward0>)
# tensor(2.0119, grad_fn=<DivBackward0>)
# tensor(1.9058, grad_fn=<DivBackward0>)
# tensor(1.9429, grad_fn=<DivBackward0>)
# Epoch 17: Training Loss 2.0944701390607015
# tensor(2.2665)
# tensor(2.3751)
# tensor(2.1141)
# tensor(2.5773)
# tensor(2.3889)
# tensor(2.7763)
# tensor(2.3640)
# tensor(2.4211)
# tensor(3.0462)
# tensor(2.1788)
# tensor(2.2815)
# tensor(2.5798)
# tensor(2.1824)
# tensor(2.4834)
# tensor(2.2083)
# tensor(2.1910)
# tensor(2.0750)
# tensor(2.6924)
# tensor(2.1879)
# tensor(2.1010)
# tensor(2.3521)
# tensor(2.2605)
# tensor(2.1539)
# tensor(2.4718)
# tensor(2.5149)
# tensor(2.7145)
# tensor(2.2011)
# tensor(2.7421)
# tensor(2.3266)
# tensor(2.2201)
# tensor(2.6072)
# tensor(2.3403)
# tensor(2.6387)
# tensor(2.2681)
# tensor(2.2548)
# tensor(2.8934)
# tensor(2.1610)
# tensor(2.2700)
# tensor(2.1855)
# tensor(2.2470)
# tensor(2.9251)
# tensor(2.1373)
# tensor(2.4711)
# tensor(1.8102)
# tensor(2.2759)
# tensor(2.2198)
# tensor(2.0099)
# tensor(2.3667)
# tensor(2.1463)
# tensor(2.6749)
# tensor(2.3513)
# tensor(1.9046)
# tensor(2.3118)
# tensor(2.1892)
# tensor(2.4850)
# tensor(2.6690)
# Epoch 17: Validation Loss 2.3488727850573405
# tensor(1.8954, grad_fn=<DivBackward0>)
# tensor(1.8859, grad_fn=<DivBackward0>)
# tensor(2.0662, grad_fn=<DivBackward0>)
# tensor(2.1312, grad_fn=<DivBackward0>)
# tensor(2.2243, grad_fn=<DivBackward0>)
# tensor(2.0879, grad_fn=<DivBackward0>)
# tensor(2.0151, grad_fn=<DivBackward0>)
# tensor(1.7397, grad_fn=<DivBackward0>)
# tensor(2.1245, grad_fn=<DivBackward0>)
# tensor(1.9364, grad_fn=<DivBackward0>)
# tensor(1.9718, grad_fn=<DivBackward0>)
# tensor(2.2643, grad_fn=<DivBackward0>)
# tensor(2.1751, grad_fn=<DivBackward0>)
# tensor(2.1530, grad_fn=<DivBackward0>)
# tensor(2.0934, grad_fn=<DivBackward0>)
# tensor(1.8862, grad_fn=<DivBackward0>)
# tensor(2.4268, grad_fn=<DivBackward0>)
# tensor(2.0198, grad_fn=<DivBackward0>)
# tensor(1.8828, grad_fn=<DivBackward0>)
# tensor(2.1168, grad_fn=<DivBackward0>)
# tensor(2.1193, grad_fn=<DivBackward0>)
# tensor(2.1457, grad_fn=<DivBackward0>)
# tensor(2.0640, grad_fn=<DivBackward0>)
# tensor(2.1018, grad_fn=<DivBackward0>)
# tensor(1.8047, grad_fn=<DivBackward0>)
# tensor(1.8875, grad_fn=<DivBackward0>)
# tensor(1.8822, grad_fn=<DivBackward0>)
# tensor(1.9464, grad_fn=<DivBackward0>)
# tensor(2.0028, grad_fn=<DivBackward0>)
# tensor(2.1237, grad_fn=<DivBackward0>)
# tensor(2.1539, grad_fn=<DivBackward0>)
# tensor(2.0695, grad_fn=<DivBackward0>)
# tensor(1.8946, grad_fn=<DivBackward0>)
# tensor(2.0066, grad_fn=<DivBackward0>)
# tensor(1.9124, grad_fn=<DivBackward0>)
# tensor(1.9500, grad_fn=<DivBackward0>)
# tensor(1.9122, grad_fn=<DivBackward0>)
# tensor(1.9718, grad_fn=<DivBackward0>)
# tensor(1.8113, grad_fn=<DivBackward0>)
# tensor(2.0001, grad_fn=<DivBackward0>)
# tensor(1.7029, grad_fn=<DivBackward0>)
# tensor(1.8718, grad_fn=<DivBackward0>)
# tensor(2.0324, grad_fn=<DivBackward0>)
# tensor(1.7338, grad_fn=<DivBackward0>)
# tensor(1.8376, grad_fn=<DivBackward0>)
# tensor(1.7518, grad_fn=<DivBackward0>)
# tensor(1.7387, grad_fn=<DivBackward0>)
# tensor(1.8948, grad_fn=<DivBackward0>)
# tensor(2.0643, grad_fn=<DivBackward0>)
# tensor(2.1232, grad_fn=<DivBackward0>)
# tensor(1.8545, grad_fn=<DivBackward0>)
# tensor(1.7801, grad_fn=<DivBackward0>)
# tensor(2.0568, grad_fn=<DivBackward0>)
# tensor(1.9698, grad_fn=<DivBackward0>)
# tensor(1.8622, grad_fn=<DivBackward0>)
# tensor(2.1556, grad_fn=<DivBackward0>)
# Epoch 18: Training Loss 1.9872780442237854
# tensor(2.6001)
# tensor(2.0457)
# tensor(1.9818)
# tensor(2.3475)
# tensor(2.1575)
# tensor(2.0170)
# tensor(1.9798)
# tensor(1.7746)
# tensor(2.5453)
# tensor(2.2541)
# tensor(1.8301)
# tensor(2.4113)
# tensor(2.5875)
# tensor(2.2949)
# tensor(1.8008)
# tensor(2.2018)
# tensor(2.3772)
# tensor(2.5724)
# tensor(2.5814)
# tensor(2.2459)
# tensor(2.6064)
# tensor(2.5959)
# tensor(2.7178)
# tensor(2.1806)
# tensor(2.4991)
# tensor(2.0997)
# tensor(2.2443)
# tensor(2.0643)
# tensor(2.4313)
# tensor(1.5201)
# tensor(2.5533)
# tensor(2.3102)
# tensor(2.0743)
# tensor(2.6011)
# tensor(2.1907)
# tensor(2.3921)
# tensor(2.7996)
# tensor(2.1791)
# tensor(2.2689)
# tensor(1.7578)
# tensor(2.2360)
# tensor(2.1077)
# tensor(1.8663)
# tensor(2.1126)
# tensor(2.4367)
# tensor(2.9632)
# tensor(2.3747)
# tensor(1.9001)
# tensor(2.2494)
# tensor(1.9189)
# tensor(2.4035)
# tensor(2.2297)
# tensor(1.8610)
# tensor(2.5208)
# tensor(2.4281)
# tensor(2.2424)
# Epoch 18: Validation Loss 2.258171024067061
# tensor(2.0521, grad_fn=<DivBackward0>)
# tensor(1.9310, grad_fn=<DivBackward0>)
# tensor(1.8149, grad_fn=<DivBackward0>)
# tensor(2.2991, grad_fn=<DivBackward0>)
# tensor(1.6062, grad_fn=<DivBackward0>)
# tensor(1.7447, grad_fn=<DivBackward0>)
# tensor(1.8523, grad_fn=<DivBackward0>)
# tensor(1.7465, grad_fn=<DivBackward0>)
# tensor(1.7436, grad_fn=<DivBackward0>)
# tensor(1.9623, grad_fn=<DivBackward0>)
# tensor(1.8821, grad_fn=<DivBackward0>)
# tensor(1.9578, grad_fn=<DivBackward0>)
# tensor(1.8975, grad_fn=<DivBackward0>)
# tensor(1.7650, grad_fn=<DivBackward0>)
# tensor(2.0398, grad_fn=<DivBackward0>)
# tensor(1.8281, grad_fn=<DivBackward0>)
# tensor(2.1524, grad_fn=<DivBackward0>)
# tensor(1.9754, grad_fn=<DivBackward0>)
# tensor(1.7958, grad_fn=<DivBackward0>)
# tensor(1.8736, grad_fn=<DivBackward0>)
# tensor(1.7602, grad_fn=<DivBackward0>)
# tensor(1.9639, grad_fn=<DivBackward0>)
# tensor(1.8380, grad_fn=<DivBackward0>)
# tensor(1.9446, grad_fn=<DivBackward0>)
# tensor(1.9017, grad_fn=<DivBackward0>)
# tensor(1.8403, grad_fn=<DivBackward0>)
# tensor(1.8607, grad_fn=<DivBackward0>)
# tensor(1.7390, grad_fn=<DivBackward0>)
# tensor(2.0938, grad_fn=<DivBackward0>)
# tensor(1.8311, grad_fn=<DivBackward0>)
# tensor(1.8918, grad_fn=<DivBackward0>)
# tensor(1.7444, grad_fn=<DivBackward0>)
# tensor(1.9205, grad_fn=<DivBackward0>)
# tensor(2.1767, grad_fn=<DivBackward0>)
# tensor(1.6989, grad_fn=<DivBackward0>)
# tensor(2.1367, grad_fn=<DivBackward0>)
# tensor(1.8389, grad_fn=<DivBackward0>)
# tensor(1.9369, grad_fn=<DivBackward0>)
# tensor(1.7309, grad_fn=<DivBackward0>)
# tensor(1.7366, grad_fn=<DivBackward0>)
# tensor(1.9395, grad_fn=<DivBackward0>)
# tensor(1.8604, grad_fn=<DivBackward0>)
# tensor(1.6918, grad_fn=<DivBackward0>)
# tensor(2.1154, grad_fn=<DivBackward0>)
# tensor(2.0069, grad_fn=<DivBackward0>)
# tensor(1.7668, grad_fn=<DivBackward0>)
# tensor(1.9458, grad_fn=<DivBackward0>)
# tensor(1.7198, grad_fn=<DivBackward0>)
# tensor(1.9435, grad_fn=<DivBackward0>)
# tensor(1.8991, grad_fn=<DivBackward0>)
# tensor(1.9020, grad_fn=<DivBackward0>)
# tensor(1.7828, grad_fn=<DivBackward0>)
# tensor(2.0339, grad_fn=<DivBackward0>)
# tensor(1.9909, grad_fn=<DivBackward0>)
# tensor(2.0099, grad_fn=<DivBackward0>)
# tensor(1.9317, grad_fn=<DivBackward0>)
# Epoch 19: Training Loss 1.893677151628903
# tensor(2.4182)
# tensor(1.8640)
# tensor(1.9757)
# tensor(2.4106)
# tensor(2.1884)
# tensor(2.0640)
# tensor(1.8900)
# tensor(1.9355)
# tensor(2.3369)
# tensor(1.8632)
# tensor(2.1696)
# tensor(2.8213)
# tensor(2.0539)
# tensor(2.1111)
# tensor(1.6557)
# tensor(2.2852)
# tensor(1.9264)
# tensor(2.3222)
# tensor(1.9038)
# tensor(2.3683)
# tensor(1.9089)
# tensor(1.9693)
# tensor(2.3379)
# tensor(2.0315)
# tensor(2.0529)
# tensor(2.2438)
# tensor(2.1431)
# tensor(1.6388)
# tensor(2.4370)
# tensor(2.2054)
# tensor(2.2314)
# tensor(1.7853)
# tensor(1.6735)
# tensor(2.2439)
# tensor(2.2866)
# tensor(2.4210)
# tensor(2.0934)
# tensor(2.4655)
# tensor(2.1374)
# tensor(1.8034)
# tensor(1.9836)
# tensor(2.4913)
# tensor(2.5075)
# tensor(2.2360)
# tensor(2.1481)
# tensor(2.2564)
# tensor(2.2188)
# tensor(2.6273)
# tensor(1.7385)
# tensor(2.3448)
# tensor(2.2012)
# tensor(1.9951)
# tensor(2.7625)
# tensor(2.3080)
# tensor(2.5416)
# tensor(2.3817)
# Epoch 19: Validation Loss 2.16011797104563
# tensor(1.8864, grad_fn=<DivBackward0>)
# tensor(1.7073, grad_fn=<DivBackward0>)
# tensor(1.8616, grad_fn=<DivBackward0>)
# tensor(1.8840, grad_fn=<DivBackward0>)
# tensor(1.7674, grad_fn=<DivBackward0>)
# tensor(1.7390, grad_fn=<DivBackward0>)
# tensor(1.9077, grad_fn=<DivBackward0>)
# tensor(1.8345, grad_fn=<DivBackward0>)
# tensor(2.0740, grad_fn=<DivBackward0>)
# tensor(1.7230, grad_fn=<DivBackward0>)
# tensor(2.1334, grad_fn=<DivBackward0>)
# tensor(2.0820, grad_fn=<DivBackward0>)
# tensor(1.8783, grad_fn=<DivBackward0>)
# tensor(1.9160, grad_fn=<DivBackward0>)
# tensor(1.8722, grad_fn=<DivBackward0>)
# tensor(1.9749, grad_fn=<DivBackward0>)
# tensor(1.7043, grad_fn=<DivBackward0>)
# tensor(1.8982, grad_fn=<DivBackward0>)
# tensor(1.7562, grad_fn=<DivBackward0>)
# tensor(1.9700, grad_fn=<DivBackward0>)
# tensor(1.6508, grad_fn=<DivBackward0>)
# tensor(1.7038, grad_fn=<DivBackward0>)
# tensor(1.6911, grad_fn=<DivBackward0>)
# tensor(1.9590, grad_fn=<DivBackward0>)
# tensor(1.8579, grad_fn=<DivBackward0>)
# tensor(1.8512, grad_fn=<DivBackward0>)
# tensor(1.6250, grad_fn=<DivBackward0>)
# tensor(1.7551, grad_fn=<DivBackward0>)
# tensor(1.8180, grad_fn=<DivBackward0>)
# tensor(1.9540, grad_fn=<DivBackward0>)
# tensor(1.7623, grad_fn=<DivBackward0>)
# tensor(1.6159, grad_fn=<DivBackward0>)
# tensor(1.8405, grad_fn=<DivBackward0>)
# tensor(1.7590, grad_fn=<DivBackward0>)
# tensor(1.9004, grad_fn=<DivBackward0>)
# tensor(1.5778, grad_fn=<DivBackward0>)
# tensor(1.9197, grad_fn=<DivBackward0>)
# tensor(2.0722, grad_fn=<DivBackward0>)
# tensor(1.4390, grad_fn=<DivBackward0>)
# tensor(1.6533, grad_fn=<DivBackward0>)
# tensor(1.9221, grad_fn=<DivBackward0>)
# tensor(1.7436, grad_fn=<DivBackward0>)
# tensor(1.8890, grad_fn=<DivBackward0>)
# tensor(1.8494, grad_fn=<DivBackward0>)
# tensor(1.6041, grad_fn=<DivBackward0>)
# tensor(1.8812, grad_fn=<DivBackward0>)
# tensor(1.5154, grad_fn=<DivBackward0>)
# tensor(1.8981, grad_fn=<DivBackward0>)
# tensor(1.8954, grad_fn=<DivBackward0>)
# tensor(1.5518, grad_fn=<DivBackward0>)
# tensor(1.9456, grad_fn=<DivBackward0>)
# tensor(1.7950, grad_fn=<DivBackward0>)
# tensor(1.7219, grad_fn=<DivBackward0>)
# tensor(1.6945, grad_fn=<DivBackward0>)
# tensor(1.7286, grad_fn=<DivBackward0>)
# tensor(1.7626, grad_fn=<DivBackward0>)
# Epoch 20: Training Loss 1.8102619626692362
# tensor(2.5688)
# tensor(1.6636)
# tensor(2.1841)
# tensor(1.6083)
# tensor(2.0345)
# tensor(2.0625)
# tensor(2.2080)
# tensor(2.1078)
# tensor(2.3334)
# tensor(1.9447)
# tensor(2.2426)
# tensor(2.0064)
# tensor(2.4754)
# tensor(1.9422)
# tensor(1.8567)
# tensor(1.9859)
# tensor(1.8618)
# tensor(1.8019)
# tensor(1.9659)
# tensor(2.0770)
# tensor(1.8084)
# tensor(1.8726)
# tensor(2.2735)
# tensor(2.2217)
# tensor(1.7716)
# tensor(2.0980)
# tensor(2.3364)
# tensor(1.5454)
# tensor(2.1596)
# tensor(2.2912)
# tensor(1.6091)
# tensor(1.8533)
# tensor(1.8894)
# tensor(2.6161)
# tensor(1.6453)
# tensor(1.9315)
# tensor(2.4528)
# tensor(2.4515)
# tensor(2.6116)
# tensor(2.4169)
# tensor(2.3673)
# tensor(2.3876)
# tensor(1.7135)
# tensor(2.4531)
# tensor(1.6609)
# tensor(2.1098)
# tensor(2.6295)
# tensor(1.9720)
# tensor(1.9696)
# tensor(2.1268)
# tensor(2.1789)
# tensor(2.2704)
# tensor(2.0646)
# tensor(1.9441)
# tensor(2.1275)
# tensor(2.0123)
# Epoch 20: Validation Loss 2.080812950219427

# %%
net = DAE()
opti = optim.SGD(net.parameters(), lr = 1e-1)
train_losses, val_losses = train(net, masked_loss, opti, training_generator, validation_generator, 20)

# %%
# Finally we plot the graphs for loss vs epochs.
plt.plot(train_losses)
plt.plot(val_losses)
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epochs')
# Out:
# Text(0.5,0,'Epochs')

# %% [markdown]
# Lets see how the network predictions compare with the actual ratings.

# %%
x, y = test_dataset.__getitem__(4)
pred = net(x)
print("Predicted Ratings: ", pred[y!=0].detach().numpy())
print("Actual Ratings: ", y[y!=0].numpy())
# Out:
# Predicted Ratings:  [3.5056705 2.0332565 3.2381735 3.9897346 3.4065752]
# Actual Ratings:  [3.5 3.5 4.  4.  4. ]

# %% [markdown]
# ## Task 5: Improving the model (10 marks)
#
# From here onwards the assignment becomes open-ended. We have so far implemented a very basic autoencoder for this task. We obtained MSE in the range 2-2.2 on the test data which is still a very huge error and not acceptable in practice. However, there are many changes that we can make in our architecture and learning algorithm to improve its performance. For example:
#
# 1. Deeper architecture, different activation functions and different hidden sizes particularly for the middle layer
# 2. Using Dropout or L2 regularization to reduce overfitting
# 3. Using Batch norm to improve training
# 4. Different optimizers like AdaDelta, RMSProp, Adam etc etc
# 5. Tuning hyperparameters like learning rate, l2 regularization constant, dropout rate etc
# 6. Using a different loss function like mean absolute error.
# 7. Creating model ensemble i.e. training multiple neural nets and then combining the outputs of all the networks to get the final output
# 8. Different algorithm all together like Variational Autoencoders, SVD etc
# 9. Train for more number of epochs, here we only trained for 20 epochs maybe more epochs can help
# 10. Early Stopping, learning rate decay
#
# After you have made the changes use your final model to get predictions on all the users using the training data. We have provided you with a file `test_hidden.dat` which contains data in the form `userId, restaurantID`. The user ratings for these restaurantIDs are missing in the training set. From our model predictions we will obtain the ratings corresponding to these restaurants and store them in file `predictions.csv` in the format `prediction` for corresponding `userId, restaurantID` in a predefined sequence. You are then required to upload this CSV file on the kaggle competition created for this assignment along with this notebook.
#
# Below we have given a function that you can run after training your final model to generate the `predictions.csv` file. You might need to change the function a little according to the way you take predictions from your model. This function assumes that you have a pytorch model instance *net* as your final model.

# %%
def get_predictions(net, train_data = train_smat):
    
    def get_test_smat(filename = 'data/test_hidden.dat'):
        sparse_dict = defaultdict(list)
        for line in open(filename):
            splitted_line = line.split(',')
            sparse_dict[int(splitted_line[0])].append((int(splitted_line[1])))

        sparse_mat = []
        sKeys = sorted(sparse_dict)
        for key in sKeys:
            sparse_mat.append(sparse_dict[key])
        
        return sparse_mat
            
            
    test_smat = get_test_smat()
    preds = []
    for i in range(len(train_data)):
        
        #Getting the actual vector from the sparse representation
        x = torch.zeros(5138)
        for j in range(len(train_data[i])):
            x[train_data[i][j][0]] = train_data[i][j][1]
        with torch.set_grad_enabled(False):
            pred = net(x).detach().numpy() ## This logic might be different for your model, change this accordingly
        
        pred = pred[test_smat[i]]
        user_rest_pred = np.concatenate([i*np.ones((len(pred),1),dtype=np.int),np.array(test_smat[i],dtype=np.int)[:,None], np.array(pred)[:,None]],axis = 1)
        preds += user_rest_pred.tolist()
        
    preds = np.array(preds)

    df = pd.DataFrame(preds)
    df[0] = df[0].astype('int')
    df[1] = df[1].astype('int')
    df[2] = df[2].astype('float16')
    df = df.drop(df.columns[[0, 1]], axis=1)
    df['index1'] = df.index.values
    df.columns = ['rating', 'id']
    df = df[['id','rating']]
    df.to_csv('predictions.csv', index=False, header=True)    
    return df

# %%
df = get_predictions(net)
df.head()
# Out:
#    id    rating
# 0   0  4.230469
# 1   1  2.468750
# 2   2  3.841797
# 3   3  3.851562
# 4   4  4.085938

# %% [markdown]
# The `predictions.csv` needs to be uploaded on the Kaggle, instructions for which will be communicated through mail.
